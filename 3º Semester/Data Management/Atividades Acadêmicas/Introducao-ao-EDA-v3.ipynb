# %%
import requests
import pandas as pd
import json
import seaborn as sns
from matplotlib import pyplot as plt
from textwrap import wrap

# %% [markdown]
# ## Introdução ao EDA (Exploratory Data Analysis)
#
# Sempre que deparamos com um desafio envolvendo dados, temos o dever de entender melhor esses dados que estamos transformando.
#
# Uma das formas mais utilizadas para entender os nossos dados é o **Processo de EDA (Exploratory Data Analysis ou Análise Exploratória de Dados)**
#
# Muitas vezes não sabemos como fazer a extração de informações e também quais objetivos sobre essa base. Uma situação exemplo é quando um cientista de dados que trabalhou anos em uma empresa do ramo de Telecomunicações, após uma recolocação de mercado está atualmente alocado em uma empresa da área de Educação. Cientistas de dados devem estar preparados para transformar dados de qualquer natureza.
#
# O EDA consiste em um processo genérico para obtenção de informações e Conclusões em bases de dados, como meio nesse processo utilizamos ferramentas de Estatística, Representações Gráficas e Modelos Matemáticos para extração dessas informações. O processo pode ser dividido em 6 Etapas:
#
# 1. **Coleta e Dominância do Conhecimento**: Obter os dados requeridos e dominar conhecimentos relacionados ao conhecimento dos dados
#
# 2. **Análise Descritiva**: Entender a estrutura e natureza dos dados, obtendo uma visão completa das características da base de dados.
#
# 3. **Consolidação dos Dados**: Modificar a estrutura e natureza dos dados conforme os objetivos estabelecidos.
#
# 3. **Análise sob a Teoria Distribuição Normal**: Entender o comportamento dos dados conforme a teoria da Distribuição Normal.
#
# 4. **Tratamento de Valores Nulos e Valores Atípicos**: A ausência de dados e valores fora da realidade conforme a Teoria Distribuição Normal  contaminam as informações geradas a partir da base analisada, portanto, esses valores devem ser mitigados ou removidos.
#
# 5. **Visualização de Dados**: A representação gráfica dos dados analisados é uma maneira eficiente de gerar informações.
#
# 6. **Extração de Padrões**: Usando algoritmos podemos verificar padrões escondidos que gráficos ou Estatística básica não alcançam, modelos de machine learning podem ser utilizados para entendimento da base analisada.
#
# **Não há um consenso sobre um definitivo do processo de EDA, o informado neste documento é um amálgama de várias bibliografias.**

# %% [markdown]
# Você sabe quanto e com o que o senadores gastaram com as verbas de Cotas para Exercício da Atividade Parlamentar dos Senadores (CEAPS)?
#
# CEAPS são gastos pertinentes à atividade parlamentar do senador ao longo do seu mandato, esses gastos são ressarcidos pela união.
#
# será que nossos representantes no senado fazem o uso consciente desses recursos?
#
# Vamos explorar a base desses gastos e prover resultados quali-quantitativos para determinar se há uma boa gestão.
#
# Dados Abertos referentes ao Senado Federal estão presentes no site https://www12.senado.leg.br/transparencia

# %% [markdown]
# ## Coleta e Dominância do Conhecimento

# %%
response = requests.get('https://adm.senado.gov.br/adm-dadosabertos/api/v1/senadores/despesas_ceaps/2018/').content

# %%
data = json.loads(response)

# %% [markdown]
# data;

# %%
df = pd.json_normalize(data)

# %%
df
# Out:
#             id  tipoDocumento   ano  mes    nomeSenador  \
# 0      2097818              7  2018    5    AÉCIO NEVES
# 1      2098479              7  2018    5    AÉCIO NEVES
# 2      2096732              7  2018    5    AÉCIO NEVES
# 3      2096740              3  2018    5    AÉCIO NEVES
# 4      2098377              6  2018    5    AÉCIO NEVES
# ...        ...            ...   ...  ...            ...
# 24487  2108809              3  2018   10  ZEZÉ PERRELLA
# 24488  2108808              3  2018   10  ZEZÉ PERRELLA
# 24489  2108805              3  2018   10  ZEZÉ PERRELLA
# 24490  2109320              4  2018   10  ZEZÉ PERRELLA
# 24491  2113622              1  2018   10  ZEZÉ PERRELLA
#
#                                              tipoDespesa         cpfCnpj  \
# 0      Aquisição de material de consumo para uso no e...  00896242000105
# 1      Contratação de consultorias, assessorias, pesq...  26894399000195
# 2      Locomoção, hospedagem, alimentação, combustíve...  05217384000627
# 3      Locomoção, hospedagem, alimentação, combustíve...  00031708000100
# 4      Passagens aéreas, aquáticas e terrestres nacio...  16978175000108
# ...                                                  ...             ...
# 24487  Aluguel de imóveis para escritório político, c...  09722379000118
# 24488  Aluguel de imóveis para escritório político, c...  09722379000118
# 24489  Aluguel de imóveis para escritório político, c...  20493131000165
# 24490  Aluguel de imóveis para escritório político, c...  02558157000162
# 24491  Locomoção, hospedagem, alimentação, combustíve...  16982779000128
#
#                                               fornecedor documento  \
# 0                            FIBRA Telecomunicações LTDA  2018/366
# 1                         JOÃO FRANCISCO MEIRELLES SILVA   2018/11
# 2      H PLUS ADMINISTRAÇÃO E HOTELARIA LTDA - SCP AT...     97567
# 3                                              SINPETAXI       s/n
# 4                        ADRIA VIAGENS E TURISMO LTDA ME    SESNQI
# ...                                                  ...       ...
# 24487            Masb 21 Empreendimento Imobiliário Ltda       s/n
# 24488            Masb 21 Empreendimento Imobiliário Ltda       S/N
# 24489                                            Prosind       S/N
# 24490                                               Vivo       s/n
# 24491                                 Lokamig Rent a Car    113329
#
#              data                                       detalhamento  \
# 0      2018-05-15                 Locação de equipamento telefônico.
# 1      2018-06-11  Contratação de serviços de apoio ao parlamenta...
# 2      2018-05-09  Hospedagem - Brasília/DF da Assessora Maria He...
# 3      2018-05-09  Maria Heloísa Cardoso - matr. 239190 - Assesso...
# 4      2018-04-25  Companhia Aérea: GOL, Localizador: SESNQI. Pas...
# ...           ...                                                ...
# 24487  2018-10-15                                               None
# 24488  2018-10-15                                               None
# 24489  2018-10-05                                               None
# 24490  2018-11-01                                               None
# 24491  2018-10-29                                               None
#
#        valorReembolsado
# 0                171.03
# 1               7000.00
# 2                424.35
# 3                 60.00
# 4               1064.52
# ...                 ...
# 24487             13.60
# 24488            225.28
# 24489            356.40
# 24490             75.99
# 24491           1795.00
#
# [24492 rows x 12 columns]

# %%
# Realizar consumo dos dados via api de forma automatizada de 2015 à 2022.

datas = [2015,2016,2017,2018,2019,2020,2021,2022]

for x in datas:
    response = requests.get('https://adm.senado.gov.br/adm-dadosabertos/api/v1/senadores/despesas_ceaps/{}/'.format(x)).content

    if x == min(datas):
        data = json.loads(response)
    else:
        data.extend(json.loads(response))
        
df = pd.json_normalize(data)

# %%
df
# Out:
#              id  tipoDocumento   ano  mes       nomeSenador  \
# 0       2002759              3  2015    2      ACIR GURGACZ
# 1       2001145              1  2015    2      ACIR GURGACZ
# 2       2005025              1  2015    2      ACIR GURGACZ
# 3       2001149              1  2015    2      ACIR GURGACZ
# 4       2001147              1  2015    2      ACIR GURGACZ
# ...         ...            ...   ...  ...               ...
# 173594  2191398              6  2022   12  ZEQUINHA MARINHO
# 173595  2192272              6  2022   12  ZEQUINHA MARINHO
# 173596  2192274              6  2022   12  ZEQUINHA MARINHO
# 173597  2192244              6  2022   12  ZEQUINHA MARINHO
# 173598  2193622              6  2022   12  ZEQUINHA MARINHO
#
#                                               tipoDespesa         cpfCnpj  \
# 0       Aluguel de imóveis para escritório político, c...     00494802863
# 1                     Divulgação da atividade parlamentar  02147085000160
# 2                     Divulgação da atividade parlamentar  84721745000130
# 3       Locomoção, hospedagem, alimentação, combustíve...  34274233009746
# 4       Locomoção, hospedagem, alimentação, combustíve...  34274233009746
# ...                                                   ...             ...
# 173594  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
# 173595  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
# 173596  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
# 173597  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
# 173598  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
#
#                                             fornecedor  documento        data  \
# 0                        GILBERTO PISELO DO NASCIMENTO     002/15  2015-02-25
# 1       ASSOCIAÇÃO COMUNITÁRIA JIPARANAENSE - ASCOJIPA        339  2015-02-02
# 2                                  O.F. CALADO EDIÇÕES     000277  2015-02-25
# 3                                        VIBRA ENERGIA  000502038  2015-02-10
# 4                                        VIBRA ENERGIA  000502045  2015-02-10
# ...                                                ...        ...         ...
# 173594                                   Exceller Tour     WIXHAI  2022-12-06
# 173595                                   Exceller Tour     WITOLM  2022-12-09
# 173596                                   Exceller Tour     THPKVQ  2022-12-20
# 173597                                   Exceller Tour     QNN9HX  2022-12-21
# 173598                                   Exceller Tour     WMQWBX  2022-12-30
#
#                                              detalhamento  valorReembolsado
# 0       Despesa com pagamento de aluguel de imóvel uti...           6000.00
# 1                     Divulgação da atividade parlamentar            300.00
# 2       Despesa com divulgação da atividade parlamenta...           2000.00
# 3       Despesa com pagamento de combustível para abas...           1728.80
# 4       Despesa com combustível para abastecimento de ...           2271.58
# ...                                                   ...               ...
# 173594  Companhia Aérea: LATAM, Localizador: WIXHAI. P...           2893.04
# 173595  Companhia Aérea: GOL, Localizador: WITOLM. Pas...           1180.19
# 173596  Companhia Aérea: TAM, Localizador: THPKVQ. Pas...           2671.90
# 173597  Companhia Aérea: AZUL, Localizador: QNN9HX. Pa...           1334.31
# 173598  Companhia Aérea: TAM, Localizador: WMQWBX. Pas...           2250.72
#
# [173599 rows x 12 columns]

# %%
df.to_csv('ceaps_senado_2015_2022.csv')

# %%
response = requests.get('https://legis.senado.leg.br/dadosabertos/senador/lista/legislatura/54/56.json').content

data = json.loads(response)

data['ListaParlamentarLegislatura']['Parlamentares']['Parlamentar'];

# %%
data = data['ListaParlamentarLegislatura']['Parlamentares']['Parlamentar']

# %%
df_senadores = pd.json_normalize(data)

# %%
df_senadores
# Out:
#     IdentificacaoParlamentar.CodigoParlamentar  \
# 0                                         5573
# 1                                         5154
# 2                                         4981
# 3                                         4815
# 4                                         5918
# ..                                         ...
# 476                                       3806
# 477                                       5144
# 478                                       5118
# 479                                       5184
# 480                                       4697
#
#     IdentificacaoParlamentar.NomeParlamentar  \
# 0                              Abel Rebouças
# 1                        Abiancy Cadoso Rosa
# 2                               Acir Gurgacz
# 3                                  Ada Mello
# 4                              Adilson Gomes
# ..                                       ...
# 476                         Zequinha Marinho
# 477                            Zeze Perrella
# 478                     Zonir Freitas Tetila
# 479                               Zé Santana
# 480                           Ângela Portela
#
#     IdentificacaoParlamentar.NomeCompletoParlamentar  \
# 0                             Abel Rebouças São José
# 1                                Abiancy Cadoso Rosa
# 2                                Acir Marcos Gurgacz
# 3                  Ada Mercedes de Mello Marques Luz
# 4                                Adilson Gomes Silva
# ..                                               ...
# 476                             José da Cruz Marinho
# 477                  José Perrella de Oliveira Costa
# 478                             Zonir Freitas Tetila
# 479                   José Ribamar Noleto de Santana
# 480                       Ângela Maria Gomes Portela
#
#     IdentificacaoParlamentar.SexoParlamentar  \
# 0                                  Masculino
# 1                                  Masculino
# 2                                  Masculino
# 3                                   Feminino
# 4                                  Masculino
# ..                                       ...
# 476                                Masculino
# 477                                Masculino
# 478                                Masculino
# 479                                Masculino
# 480                                 Feminino
#
#     IdentificacaoParlamentar.FormaTratamento  \
# 0                                   Senador
# 1                                   Senador
# 2                                   Senador
# 3                                  Senadora
# 4                                   Senador
# ..                                       ...
# 476                                 Senador
# 477                                 Senador
# 478                                 Senador
# 479                                 Senador
# 480                                Senadora
#
#     IdentificacaoParlamentar.SiglaPartidoParlamentar  \
# 0                                                PDT
# 1                                          CIDADANIA
# 2                                                PDT
# 3                                                PTB
# 4                                                NaN
# ..                                               ...
# 476                                               PL
# 477                                              MDB
# 478                                               PT
# 479                                              MDB
# 480                                              PDT
#
#     Mandatos.Mandato.CodigoMandato Mandatos.Mandato.UfParlamentar  \
# 0                              492                             BA
# 1                              487                             PA
# 2                              NaN                            NaN
# 3                              345                             AL
# 4                              526                             PE
# ..                             ...                            ...
# 476                            566                             PA
# 477                            441                             MG
# 478                            447                             MS
# 479                            488                             PI
# 480                            486                             RR
#
#     Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura  \
# 0                                                   55
# 1                                                   54
# 2                                                  NaN
# 3                                                   53
# 4                                                   56
# ..                                                 ...
# 476                                                 56
# 477                                                 54
# 478                                                 54
# 479                                                 54
# 480                                                 54
#
#     Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio  ...  \
# 0                                           2015-02-01        ...
# 1                                           2011-02-01        ...
# 2                                                  NaN        ...
# 3                                           2007-02-01        ...
# 4                                           2019-02-01        ...
# ..                                                 ...        ...
# 476                                         2019-02-01        ...
# 477                                         2011-02-01        ...
# 478                                         2011-02-01        ...
# 479                                         2011-02-01        ...
# 480                                         2011-02-01        ...
#
#                                       Mandatos.Mandato  \
# 0                                                  NaN
# 1                                                  NaN
# 2    [{'CodigoMandato': '515', 'UfParlamentar': 'RO...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 476                                                NaN
# 477                                                NaN
# 478                                                NaN
# 479                                                NaN
# 480                                                NaN
#
#     Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                 2505
# 4                                                  NaN
# ..                                                 ...
# 476                                               2916
# 477                                               2643
# 478                                                NaN
# 479                                               2878
# 480                                               2582
#
#     Mandatos.Mandato.Exercicios.Exercicio.DataInicio  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                         2008-09-15
# 4                                                NaN
# ..                                               ...
# 476                                       2019-02-01
# 477                                       2011-07-11
# 478                                              NaN
# 479                                       2018-12-13
# 480                                       2011-02-01
#
#     Mandatos.Mandato.Exercicios.Exercicio.DataFim  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                      2009-01-10
# 4                                             NaN
# ..                                            ...
# 476                                           NaN
# 477                                    2019-01-31
# 478                                           NaN
# 479                                    2019-01-31
# 480                                    2019-01-31
#
#     Mandatos.Mandato.Exercicios.Exercicio.SiglaCausaAfastamento  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  RET
# 4                                                  NaN
# ..                                                 ...
# 476                                                NaN
# 477                                                TER
# 478                                                NaN
# 479                                                TER
# 480                                                TER
#
#     Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                   Retorno do titular
# 4                                                  NaN
# ..                                                 ...
# 476                                                NaN
# 477                                 Término do mandato
# 478                                                NaN
# 479                                 Término do mandato
# 480                                 Término do mandato
#
#     Mandatos.Mandato.Exercicios.Exercicio.DataLeitura  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                          2008-09-15
# 4                                                 NaN
# ..                                                ...
# 476                                               NaN
# 477                                               NaN
# 478                                               NaN
# 479                                               NaN
# 480                                               NaN
#
#     IdentificacaoParlamentar.UfParlamentar  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 476                                     PA
# 477                                    NaN
# 478                                    NaN
# 479                                    NaN
# 480                                    NaN
#
#                    Mandatos.Mandato.Suplentes.Suplente  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 476  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 477                                                NaN
# 478                                                NaN
# 479                                                NaN
# 480  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
#
#     Mandatos.Mandato.Exercicios.Exercicio
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 476                                   NaN
# 477                                   NaN
# 478                                   NaN
# 479                                   NaN
# 480                                   NaN
#
# [481 rows x 36 columns]

# %%
df_senadores.to_csv('senadores_2015_2022.csv')

# %%
df_senadores = pd.read_csv('senadores_2015_2022.csv')

# %%
df = pd.read_csv('ceaps_senado_2015_2022.csv')

# %% [markdown]
# ## Analise Descritiva

# %% [markdown]
# #### DF

# %%
df.ano.min()
# Out:
# 2015

# %%
df.ano.max()
# Out:
# 2022

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'tipoDocumento', 'ano', 'mes', 'nomeSenador',
#        'tipoDespesa', 'cpfCnpj', 'fornecedor', 'documento', 'data',
#        'detalhamento', 'valorReembolsado'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173599 entries, 0 to 173598
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        173599 non-null  int64
#  1   id                173599 non-null  int64
#  2   tipoDocumento     173599 non-null  int64
#  3   ano               173599 non-null  int64
#  4   mes               173599 non-null  int64
#  5   nomeSenador       173599 non-null  object
#  6   tipoDespesa       173599 non-null  object
#  7   cpfCnpj           173599 non-null  int64
#  8   fornecedor        173599 non-null  object
#  9   documento         162007 non-null  object
#  10  data              173599 non-null  object
#  11  detalhamento      121676 non-null  object
#  12  valorReembolsado  173599 non-null  float64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 17.2+ MB

# %%
df[['valorReembolsado']].describe()
# Out:
#        valorReembolsado
# count     173599.000000
# mean        1153.939511
# std         2887.785539
# min        -1500.000000
# 25%          135.000000
# 50%          356.060000
# 75%         1200.000000
# max       270000.000000

# %%
# Qual é o registro com Valor Minímo da Coluna valorReembolsado?
df[df['valorReembolsado'] == df['valorReembolsado'].min()]
# Out:
#       Unnamed: 0       id  tipoDocumento   ano  mes     nomeSenador  \
# 7981        7981  2001228              3  2015    2  GLADSON CAMELI
#
#                                             tipoDespesa         cpfCnpj  \
# 7981  Aluguel de imóveis para escritório político, c...  63600449000100
#
#                                              fornecedor documento        data  \
# 7981  Arras Adm. de Bens Imóveis Limpeza e Conservaç...       NaN  2015-01-15
#
#                                            detalhamento  valorReembolsado
# 7981  Contrato de locação de Imóvel comercial do esc...           -1500.0

# %%
# Qual é o registro com Valor Máximo da Coluna valorReembolsado?
df[df['valorReembolsado'] == df['valorReembolsado'].max()]
# Out:
#        Unnamed: 0       id  tipoDocumento   ano  mes      nomeSenador  \
# 57562       57562  2090997              1  2017   12  DAVI ALCOLUMBRE
#
#                                tipoDespesa         cpfCnpj  \
# 57562  Divulgação da atividade parlamentar  29337655000131
#
#                                   fornecedor documento        data  \
# 57562  Start print Comunicação Visual Eireli        36  2018-03-15
#
#       detalhamento  valorReembolsado
# 57562          NaN          270000.0

# %% [markdown]
# #### DF_SENADORES

# %%
df_senadores.columns
# Out:
# Index(['Unnamed: 0', 'IdentificacaoParlamentar.CodigoParlamentar',
#        'IdentificacaoParlamentar.NomeParlamentar',
#        'IdentificacaoParlamentar.NomeCompletoParlamentar',
#        'IdentificacaoParlamentar.SexoParlamentar',
#        'IdentificacaoParlamentar.FormaTratamento',
#        'IdentificacaoParlamentar.SiglaPartidoParlamentar',
#        'Mandatos.Mandato.CodigoMandato', 'Mandatos.Mandato.UfParlamentar',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataFim',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.NumeroLegislatura',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.DataInicio',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.DataFim',
#        'Mandatos.Mandato.DescricaoParticipacao',
#        'Mandatos.Mandato.Titular.DescricaoParticipacao',
#        'Mandatos.Mandato.Titular.CodigoParlamentar',
#        'Mandatos.Mandato.Titular.NomeParlamentar',
#        'Mandatos.Mandato.Suplentes.Suplente.DescricaoParticipacao',
#        'Mandatos.Mandato.Suplentes.Suplente.CodigoParlamentar',
#        'Mandatos.Mandato.Suplentes.Suplente.NomeParlamentar',
#        'IdentificacaoParlamentar.CodigoPublicoNaLegAtual',
#        'IdentificacaoParlamentar.UrlFotoParlamentar',
#        'IdentificacaoParlamentar.UrlPaginaParlamentar',
#        'IdentificacaoParlamentar.UrlPaginaParticular',
#        'IdentificacaoParlamentar.EmailParlamentar',
#        'Mandatos.Mandato.Suplentes.Suplente',
#        'Mandatos.Mandato.Exercicios.Exercicio',
#        'Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio',
#        'Mandatos.Mandato.Exercicios.Exercicio.DataInicio',
#        'Mandatos.Mandato.Exercicios.Exercicio.DataFim',
#        'Mandatos.Mandato.Exercicios.Exercicio.SiglaCausaAfastamento',
#        'Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento',
#        'IdentificacaoParlamentar.UfParlamentar',
#        'Mandatos.Mandato.Exercicios.Exercicio.DataLeitura',
#        'Mandatos.Mandato'],
#       dtype='object')

# %%
df_senadores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 37 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Unnamed: 0                                                       406 non-null    int64
#  1   IdentificacaoParlamentar.CodigoParlamentar                       406 non-null    int64
#  2   IdentificacaoParlamentar.NomeParlamentar                         406 non-null    object
#  3   IdentificacaoParlamentar.NomeCompletoParlamentar                 406 non-null    object
#  4   IdentificacaoParlamentar.SexoParlamentar                         406 non-null    object
#  5   IdentificacaoParlamentar.FormaTratamento                         406 non-null    object
#  6   IdentificacaoParlamentar.SiglaPartidoParlamentar                 323 non-null    object
#  7   Mandatos.Mandato.CodigoMandato                                   394 non-null    float64
#  8   Mandatos.Mandato.UfParlamentar                                   394 non-null    object
#  9   Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura  394 non-null    float64
#  10  Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio         394 non-null    object
#  11  Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataFim            394 non-null    object
#  12  Mandatos.Mandato.SegundaLegislaturaDoMandato.NumeroLegislatura   394 non-null    float64
#  13  Mandatos.Mandato.SegundaLegislaturaDoMandato.DataInicio          394 non-null    object
#  14  Mandatos.Mandato.SegundaLegislaturaDoMandato.DataFim             394 non-null    object
#  15  Mandatos.Mandato.DescricaoParticipacao                           394 non-null    object
#  16  Mandatos.Mandato.Titular.DescricaoParticipacao                   272 non-null    object
#  17  Mandatos.Mandato.Titular.CodigoParlamentar                       272 non-null    float64
#  18  Mandatos.Mandato.Titular.NomeParlamentar                         272 non-null    object
#  19  Mandatos.Mandato.Suplentes.Suplente.DescricaoParticipacao        272 non-null    object
#  20  Mandatos.Mandato.Suplentes.Suplente.CodigoParlamentar            272 non-null    float64
#  21  Mandatos.Mandato.Suplentes.Suplente.NomeParlamentar              272 non-null    object
#  22  IdentificacaoParlamentar.CodigoPublicoNaLegAtual                 118 non-null    float64
#  23  IdentificacaoParlamentar.UrlFotoParlamentar                      219 non-null    object
#  24  IdentificacaoParlamentar.UrlPaginaParlamentar                    219 non-null    object
#  25  IdentificacaoParlamentar.UrlPaginaParticular                     27 non-null     object
#  26  IdentificacaoParlamentar.EmailParlamentar                        211 non-null    object
#  27  Mandatos.Mandato.Suplentes.Suplente                              122 non-null    object
#  28  Mandatos.Mandato.Exercicios.Exercicio                            63 non-null     object
#  29  Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio            138 non-null    float64
#  30  Mandatos.Mandato.Exercicios.Exercicio.DataInicio                 138 non-null    object
#  31  Mandatos.Mandato.Exercicios.Exercicio.DataFim                    105 non-null    object
#  32  Mandatos.Mandato.Exercicios.Exercicio.SiglaCausaAfastamento      105 non-null    object
#  33  Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento  105 non-null    object
#  34  IdentificacaoParlamentar.UfParlamentar                           75 non-null     object
#  35  Mandatos.Mandato.Exercicios.Exercicio.DataLeitura                14 non-null     object
#  36  Mandatos.Mandato                                                 12 non-null     object
# dtypes: float64(7), int64(2), object(28)
# memory usage: 117.5+ KB

# %%
df_senadores.head(10)
# Out:
#    Unnamed: 0  IdentificacaoParlamentar.CodigoParlamentar  \
# 0           0                                        5573
# 1           1                                        5154
# 2           2                                        4981
# 3           3                                        5918
# 4           4                                        5625
# 5           5                                        6026
# 6           6                                        5170
# 7           7                                        5140
# 8           8                                        5923
# 9           9                                        5982
#
#   IdentificacaoParlamentar.NomeParlamentar  \
# 0                            Abel Rebouças
# 1                      Abiancy Cadoso Rosa
# 2                             Acir Gurgacz
# 3                            Adilson Gomes
# 4                 Adilson Silva dos Santos
# 5                           Afonso Parente
# 6                    Agimiro Dias da Costa
# 7                          Airton Sandoval
# 8                            Alberto David
# 9                        Alessandro Vieira
#
#   IdentificacaoParlamentar.NomeCompletoParlamentar  \
# 0                           Abel Rebouças São José
# 1                              Abiancy Cadoso Rosa
# 2                              Acir Marcos Gurgacz
# 3                              Adilson Gomes Silva
# 4                         Adilson Silva dos Santos
# 5                      Afonso Valter Parente Pinto
# 6                            Agimiro Dias da Costa
# 7                          Airton Sandoval Santana
# 8                           Alberto da Silva David
# 9                                Alessandro Vieira
#
#   IdentificacaoParlamentar.SexoParlamentar  \
# 0                                Masculino
# 1                                Masculino
# 2                                Masculino
# 3                                Masculino
# 4                                Masculino
# 5                                Masculino
# 6                                Masculino
# 7                                Masculino
# 8                                Masculino
# 9                                Masculino
#
#   IdentificacaoParlamentar.FormaTratamento  \
# 0                                 Senador
# 1                                 Senador
# 2                                 Senador
# 3                                 Senador
# 4                                 Senador
# 5                                 Senador
# 6                                 Senador
# 7                                 Senador
# 8                                 Senador
# 9                                 Senador
#
#   IdentificacaoParlamentar.SiglaPartidoParlamentar  \
# 0                                              PDT
# 1                                        CIDADANIA
# 2                                              PDT
# 3                                              NaN
# 4                                              PEN
# 5                                              NaN
# 6                                             PSDB
# 7                                              MDB
# 8                                              NaN
# 9                                             PSDB
#
#    Mandatos.Mandato.CodigoMandato Mandatos.Mandato.UfParlamentar  \
# 0                           492.0                             BA
# 1                           487.0                             PA
# 2                           515.0                             RO
# 3                           526.0                             PE
# 4                           497.0                             RS
# 5                           578.0                             RR
# 6                           451.0                             TO
# 7                           485.0                             SP
# 8                           522.0                             AP
# 9                           559.0                             SE
#
#    Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura  ...  \
# 0                                               55.0                ...
# 1                                               54.0                ...
# 2                                               55.0                ...
# 3                                               56.0                ...
# 4                                               55.0                ...
# 5                                               56.0                ...
# 6                                               54.0                ...
# 7                                               54.0                ...
# 8                                               56.0                ...
# 9                                               56.0                ...
#
#                  Mandatos.Mandato.Suplentes.Suplente  \
# 0                                                NaN
# 1                                                NaN
# 2  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  [{'DescricaoParticipacao': '1º Suplente', 'Cod...
#
#                Mandatos.Mandato.Exercicios.Exercicio  \
# 0                                                NaN
# 1                                                NaN
# 2  [{'CodigoExercicio': '2810', 'DataInicio': '20...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                             2827.0
# 8                                                NaN
# 9                                             2888.0
#
#   Mandatos.Mandato.Exercicios.Exercicio.DataInicio  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                       2017-03-09
# 8                                              NaN
# 9                                       2019-02-01
#
#   Mandatos.Mandato.Exercicios.Exercicio.DataFim  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                    2018-12-31
# 8                                           NaN
# 9                                           NaN
#
#   Mandatos.Mandato.Exercicios.Exercicio.SiglaCausaAfastamento  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                RET
# 8                                                NaN
# 9                                                NaN
#
#   Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                 Retorno do titular
# 8                                                NaN
# 9                                                NaN
#
#    IdentificacaoParlamentar.UfParlamentar  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                      SE
#
#   Mandatos.Mandato.Exercicios.Exercicio.DataLeitura Mandatos.Mandato
# 0                                               NaN              NaN
# 1                                               NaN              NaN
# 2                                               NaN              NaN
# 3                                               NaN              NaN
# 4                                               NaN              NaN
# 5                                               NaN              NaN
# 6                                               NaN              NaN
# 7                                               NaN              NaN
# 8                                               NaN              NaN
# 9                                               NaN              NaN
#
# [10 rows x 37 columns]

# %% [markdown]
# Considerações da Analise Descritiva para próxima etapa de Consolidação dos Dados:
#
# Ações Realizadas:
# 1. Carga dos Dados via API.
# 2. União documentos.
#
# Ações Futuras:
# 1. Coluna Date está em string, transformar para datetime.
# 2. Existe Números Negativos Na Coluna valorReembolsado, verificar tratativa.
# 3. Apagar Colunas desnecessárias
# 4. Ajustar Nome Parlamentar
# 5. Merge das Tabelas df e df_senadores

# %% [markdown]
# ## Consolidação dos Dados

# %% [markdown]
# #### DF

# %%
# Testar se a col data pode ser transformada em datetime
#df['data'].astype('datetime64')

# %% [markdown]
# Vemos que não possivel transformar toda a coluna data em datetime, o erro acusado que existes valores na coluna fora calendário do Pandas.

# %%
# filtro se exite mesmo um registo com esses valores
df[df['data'] == '2915-10-06']
# Out:
#        Unnamed: 0       id  tipoDocumento   ano  mes         nomeSenador  \
# 10501       10501  2029364              6  2015   10  JOÃO ALBERTO SOUZA
#
#                                              tipoDespesa         cpfCnpj  \
# 10501  Passagens aéreas, aquáticas e terrestres nacio...  16978175000108
#
#                          fornecedor documento        data  \
# 10501  ADRIA VIAGENS E TURISMO LTDA       NaN  2915-10-06
#
#                                             detalhamento  valorReembolsado
# 10501  Companhia Aérea: GOL, Localizador: HF2VJM. Pas...            993.46

# %%
# Podemos transformar os dados em data mitigando os erros com o coerce
# Criamos a coluna data_ para testes
df['data_'] = pd.to_datetime(df['data'], errors = 'coerce')

# %%
# Filtro com valores de data com problemas
df[df['data_'].isna()]
# Out:
#         Unnamed: 0       id  tipoDocumento   ano  mes         nomeSenador  \
# 10501        10501  2029364              6  2015   10  JOÃO ALBERTO SOUZA
# 12030        12030  2016913              7  2015    8       JOSÉ AGRIPINO
# 12390        12390  2011103              6  2015    4       JOSÉ MEDEIROS
# 18666        18666  2008125              6  2015    4         PAULO ROCHA
# 18686        18686  2008124              6  2015    4         PAULO ROCHA
# 22863        22863  2007486              6  2015    5       TELMÁRIO MOTA
# 28340        28340  2050224              4  2016   10    ARMANDO MONTEIRO
# 38557        38557  2034257              7  2016    4       JOSÉ MEDEIROS
# 39761        39761  2051549              7  2016   10         KÁTIA ABREU
# 39899        39899  2036344              2  2016    4          JOSÉ SERRA
# 43906        43906  2051216              6  2016   10          PAULO PAIM
# 59607        59607  2083148              3  2017   12       ELMANO FÉRRER
# 68210        68210  2084741              7  2017   11         LÚCIA VÂNIA
# 68894        68894  2084537              4  2017   11         MAGNO MALTA
# 71383        71383  2060535              6  2017    3         PAULO ROCHA
# 79587        79587  2062578              6  2017    3       ZEZÉ PERRELLA
# 94038        94038  2096075              3  2018    3         LÚCIA VÂNIA
# 96709        96709  2111217              7  2018   11          PAULO PAIM
# 115573      115573  2114251              3  2019    1         LÚCIA VÂNIA
# 136280      136280  2144535              7  2020    5      PLÍNIO VALÉRIO
# 142406      142406  2169237              6  2021   11        CARLOS VIANA
#
#                                               tipoDespesa         cpfCnpj  \
# 10501   Passagens aéreas, aquáticas e terrestres nacio...  16978175000108
# 12030                       Serviços de Segurança Privada  10209529000173
# 12390   Passagens aéreas, aquáticas e terrestres nacio...  16978175000108
# 18666   Passagens aéreas, aquáticas e terrestres nacio...   2012862000160
# 18686   Passagens aéreas, aquáticas e terrestres nacio...   7575651000159
# 22863   Passagens aéreas, aquáticas e terrestres nacio...  12795601000117
# 28340   Aluguel de imóveis para escritório político, c...  41054867000107
# 38557   Locomoção, hospedagem, alimentação, combustíve...  12262251000123
# 39761   Locomoção, hospedagem, alimentação, combustíve...  56548779000139
# 39899   Locomoção, hospedagem, alimentação, combustíve...  52791571000195
# 43906   Passagens aéreas, aquáticas e terrestres nacio...  33937681000178
# 59607   Aluguel de imóveis para escritório político, c...   6277571000154
# 68210   Locomoção, hospedagem, alimentação, combustíve...   2072286000650
# 68894   Aluguel de imóveis para escritório político, c...   2558157000162
# 71383   Passagens aéreas, aquáticas e terrestres nacio...   7575651000159
# 79587   Passagens aéreas, aquáticas e terrestres nacio...  33937681000178
# 94038   Aluguel de imóveis para escritório político, c...   2266468000158
# 96709   Locomoção, hospedagem, alimentação, combustíve...  22484857000167
# 115573  Aluguel de imóveis para escritório político, c...   8573731000138
# 136280                Divulgação da atividade parlamentar  27209437000196
# 142406  Passagens aéreas, aquáticas e terrestres nacio...  16978175000108
#
#                                                fornecedor    documento  \
# 10501                        ADRIA VIAGENS E TURISMO LTDA          NaN
# 12030         Branco Oliveira Limpeza e Conservação Ltda.          034
# 12390                                       ADRIA VIAGENS          NaN
# 18666                               TAM Linhas Aéreas S.A       XGUHHW
# 18686                              VRG Linhas Aereas S.A.       THIEUG
# 22863                    GLOBAL VIAGENS EVENTOS E TURISMO       010/15
# 28340                                 Jadan Office Center   1101610021
# 38557                               HOTEL GRAN ODARA LTDA        65509
# 39761   Transamérica Comercial e Serviços Ltda SCP La ...     00038600
# 39899                          A Ferreira Automóveis LTDA       541327
# 43906                                               LATAM       5HJBB4
# 59607                       IMOBILIÁRIA SANTA CLARA LTDA.        73859
# 68210                          Petroil Combustívels Ltda.         5021
# 68894                              Telefonica Brasil S.A.  05162707630
# 71383                              VRG Linhas Aereas S.A.       PKIP6Q
# 79587                                               LATAM       3WI7U2
# 94038                                    URBS Imobiliária       177528
# 96709                   Britim Combustíveis Eirelli - EPP       108199
# 115573  LDE Contabilidade e Administração de Condomíni...      0107007
# 136280                 Excelsior Comunicação Digital Ltda       2020/9
# 142406                       ADRIA VIAGENS E TURISMO LTDA       YK1QHD
#
#               data                                       detalhamento  \
# 10501   2915-10-06  Companhia Aérea: GOL, Localizador: HF2VJM. Pas...
# 12030   0201-08-25                                                NaN
# 12390   5015-02-24  Companhia Aérea: AVIANCA, Localizador: 42BZ8L....
# 18666   0215-04-21  Companhia Aérea: TAM, Localizador: XGUHHW. Pas...
# 18686   0215-04-22  Companhia Aérea: GOL, Localizador: THIEUG. Pas...
# 22863   5201-05-08  Companhia Aérea: TAM, Localizador: 5MHYZ3. Pas...
# 28340   5017-07-20  Taxa de condomínio do escritório parlamentar, ...
# 38557   3016-04-02                             despesa com hospedagem
# 39761   0200-10-30  Hospedagem (R$ 648,44) e alimentação (R$ 40,00...
# 39899   0216-04-03  Senador José Serra - Aquisição de combustível ...
# 43906   0206-10-30  Companhia Aérea: LATAM, Localizador: 5HJBB4. P...
# 59607   1017-02-11  DESPESA COM PAGAMENTO DE ALUGUEL DO ESCRITÓRIO...
# 68210   1201-12-06  Aquisição de combustível para veículo utilizad...
# 68894   0201-11-08  Despesa com imóvel político: pagamento de tele...
# 71383   0201-03-01  Companhia Aérea: GOL, Localizador: PKIP6Q. Pas...
# 79587   0217-02-12  Companhia Aérea: LATAM, Localizador: 3WI7U2. P...
# 94038   0208-05-08  Pagamento de taxa de aluguel referente ao imóv...
# 96709   1201-11-22  Aquisição de combustível para veículos utiliza...
# 115573  0219-01-30                                   Taxa condominial
# 136280  0202-05-04                                                NaN
# 142406  0202-10-28  Companhia Aérea: AZUL, Localizador: YK1QHD. Pa...
#
#         valorReembolsado data_
# 10501             993.46   NaT
# 12030            4029.11   NaT
# 12390             821.25   NaT
# 18666             853.93   NaT
# 18686             813.93   NaT
# 22863            2659.35   NaT
# 28340             811.89   NaT
# 38557             259.90   NaT
# 39761             688.44   NaT
# 39899             158.58   NaT
# 43906            1860.79   NaT
# 59607            2973.45   NaT
# 68210             100.00   NaT
# 68894             421.28   NaT
# 71383             731.79   NaT
# 79587             430.51   NaT
# 94038            1200.00   NaT
# 96709             100.00   NaT
# 115573            271.26   NaT
# 136280           1150.00   NaT
# 142406            339.90   NaT

# %%
# Ajuste as datas com problemas no filtro acima

for index, row in df[df['data_'].isna()].iterrows():
    dia = row['data'][-2:]
    df['data'].iloc[index]  = '{}-{}-{}'.format(row['ano'],row['mes'],dia)
# Out:
# C:\Users\pedroDesktop\AppData\Local\Temp\ipykernel_21488\2335391355.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['data'].iloc[index]  = '{}-{}-{}'.format(row['ano'],row['mes'],dia)

# %%
# Teste a tratativa acima transforma a coluna date em datetime
df['data'].astype('datetime64')
# Out:
# 0        2015-02-25
# 1        2015-02-02
# 2        2015-02-25
# 3        2015-02-10
# 4        2015-02-10
#             ...
# 173594   2022-12-06
# 173595   2022-12-09
# 173596   2022-12-20
# 173597   2022-12-21
# 173598   2022-12-30
# Name: data, Length: 173599, dtype: datetime64[ns]

# %%
# Transformar os dados para datetime
df['data'] = df['data'].astype('datetime64')
# Apagar a coluna de teste
del df['data_']

# %%
# Verificar se existe valores negativos na col valorReembolsado
df[df['valorReembolsado'] <= 0]
# Out:
#        Unnamed: 0       id  tipoDocumento   ano  mes     nomeSenador  \
# 7981         7981  2001228              3  2015    2  GLADSON CAMELI
# 57402       57402  2068568              7  2017    5    DÁRIO BERGER
#
#                                              tipoDespesa         cpfCnpj  \
# 7981   Aluguel de imóveis para escritório político, c...  63600449000100
# 57402  Contratação de consultorias, assessorias, pesq...  73228876000163
#
#                                               fornecedor documento       data  \
# 7981   Arras Adm. de Bens Imóveis Limpeza e Conservaç...       NaN 2015-01-15
# 57402                             TV CLIPAGEM LTDA. EPP.    001661 2017-06-02
#
#                                             detalhamento  valorReembolsado
# 7981   Contrato de locação de Imóvel comercial do esc...           -1500.0
# 57402  Despesa com Monitoramento de Informação Jornal...            -243.4

# %%
# Transforme os valores menores de 0 em Absoluto
df['valorReembolsado'] = abs(df['valorReembolsado'])

# %% [markdown]
# #### DF_SENADORES

# %%
# Vamos apagar colunas desnecessárias
del df_senadores['IdentificacaoParlamentar.UrlPaginaParlamentar']
del df_senadores['IdentificacaoParlamentar.EmailParlamentar'] 
del df_senadores['IdentificacaoParlamentar.UrlPaginaParticular']
del df_senadores['IdentificacaoParlamentar.UrlFotoParlamentar']
del df_senadores['IdentificacaoParlamentar.CodigoPublicoNaLegAtual']
del df_senadores['IdentificacaoParlamentar.FormaTratamento']
del df_senadores['Mandatos.Mandato.Exercicios.Exercicio.SiglaCausaAfastamento']
del df_senadores['IdentificacaoParlamentar.UfParlamentar']
del df_senadores['Mandatos.Mandato.Exercicios.Exercicio.DataLeitura']
del df_senadores['Mandatos.Mandato']
del df_senadores['Mandatos.Mandato.Suplentes.Suplente']
del df_senadores['Mandatos.Mandato.Exercicios.Exercicio']

# %%
# Transforme o nome parlamentar em maiuscula
df_senadores['IdentificacaoParlamentar.NomeParlamentar'] = df_senadores['IdentificacaoParlamentar.NomeParlamentar'].apply(lambda x: x.upper())

# %%
# Corrija a Tipagem das colunas de natureza data em objeto para datetime
df_senadores['Mandatos.Mandato.Exercicios.Exercicio.DataInicio'] = pd.to_datetime(df_senadores['Mandatos.Mandato.Exercicios.Exercicio.DataInicio'], errors = 'coerce')
df_senadores['Mandatos.Mandato.Exercicios.Exercicio.DataFim'] = pd.to_datetime(df_senadores['Mandatos.Mandato.Exercicios.Exercicio.DataFim'], errors = 'coerce')

df_senadores['Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio'] = pd.to_datetime(df_senadores['Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio'], errors = 'coerce')
df_senadores['Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataFim'] = pd.to_datetime(df_senadores['Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataFim'], errors = 'coerce')
       
df_senadores['Mandatos.Mandato.SegundaLegislaturaDoMandato.DataInicio'] = pd.to_datetime(df_senadores['Mandatos.Mandato.SegundaLegislaturaDoMandato.DataInicio'], errors = 'coerce')
df_senadores['Mandatos.Mandato.SegundaLegislaturaDoMandato.DataFim'] = pd.to_datetime(df_senadores['Mandatos.Mandato.SegundaLegislaturaDoMandato.DataFim'], errors = 'coerce')

# %%
# Coluna de id para int
df_senadores['IdentificacaoParlamentar.CodigoParlamentar'] = df_senadores['IdentificacaoParlamentar.CodigoParlamentar'].astype(int)

# %% [markdown]
# #### Merge dos datasets DF e DF_SENADORES
#
# Para fazer uma união entre bases de dados temos que procurar chaves primárias em comum entre as duas bases em questão.
#
# Qual seria essas chaves?

# %%
df_senadores.head(5)
# Out:
#    Unnamed: 0  IdentificacaoParlamentar.CodigoParlamentar  \
# 0           0                                        5573
# 1           1                                        5154
# 2           2                                        4981
# 3           3                                        5918
# 4           4                                        5625
#
#   IdentificacaoParlamentar.NomeParlamentar  \
# 0                            ABEL REBOUÇAS
# 1                      ABIANCY CADOSO ROSA
# 2                             ACIR GURGACZ
# 3                            ADILSON GOMES
# 4                 ADILSON SILVA DOS SANTOS
#
#   IdentificacaoParlamentar.NomeCompletoParlamentar  \
# 0                           Abel Rebouças São José
# 1                              Abiancy Cadoso Rosa
# 2                              Acir Marcos Gurgacz
# 3                              Adilson Gomes Silva
# 4                         Adilson Silva dos Santos
#
#   IdentificacaoParlamentar.SexoParlamentar  \
# 0                                Masculino
# 1                                Masculino
# 2                                Masculino
# 3                                Masculino
# 4                                Masculino
#
#   IdentificacaoParlamentar.SiglaPartidoParlamentar  \
# 0                                              PDT
# 1                                        CIDADANIA
# 2                                              PDT
# 3                                              NaN
# 4                                              PEN
#
#    Mandatos.Mandato.CodigoMandato Mandatos.Mandato.UfParlamentar  \
# 0                           492.0                             BA
# 1                           487.0                             PA
# 2                           515.0                             RO
# 3                           526.0                             PE
# 4                           497.0                             RS
#
#    Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura  \
# 0                                               55.0
# 1                                               54.0
# 2                                               55.0
# 3                                               56.0
# 4                                               55.0
#
#   Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio  ...  \
# 0                                         2015-02-01        ...
# 1                                         2011-02-01        ...
# 2                                         2015-02-01        ...
# 3                                         2019-02-01        ...
# 4                                         2015-02-01        ...
#
#   Mandatos.Mandato.Titular.DescricaoParticipacao  \
# 0                                        Titular
# 1                                        Titular
# 2                                            NaN
# 3                                        Titular
# 4                                        Titular
#
#    Mandatos.Mandato.Titular.CodigoParlamentar  \
# 0                                      5523.0
# 1                                      3634.0
# 2                                         NaN
# 3                                      4545.0
# 4                                      5533.0
#
#   Mandatos.Mandato.Titular.NomeParlamentar  \
# 0                             Otto Alencar
# 1                            Flexa Ribeiro
# 2                                      NaN
# 3                       Jarbas Vasconcelos
# 4                           Lasier Martins
#
#   Mandatos.Mandato.Suplentes.Suplente.DescricaoParticipacao  \
# 0                                        2º Suplente
# 1                                        1º Suplente
# 2                                                NaN
# 3                                        1º Suplente
# 4                                        1º Suplente
#
#   Mandatos.Mandato.Suplentes.Suplente.CodigoParlamentar  \
# 0                                             5575.0
# 1                                              380.0
# 2                                                NaN
# 3                                             5917.0
# 4                                             5623.0
#
#   Mandatos.Mandato.Suplentes.Suplente.NomeParlamentar  \
# 0                                           Marizete
# 1                                     Nicias Ribeiro
# 2                                                NaN
# 3                                    Fernando Dueire
# 4                                Christopher Goulart
#
#    Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Mandatos.Mandato.Exercicios.Exercicio.DataInicio  \
# 0                                              NaT
# 1                                              NaT
# 2                                              NaT
# 3                                              NaT
# 4                                              NaT
#
#   Mandatos.Mandato.Exercicios.Exercicio.DataFim  \
# 0                                           NaT
# 1                                           NaT
# 2                                           NaT
# 3                                           NaT
# 4                                           NaT
#
#    Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 25 columns]

# %%
df_senadores.columns
# Out:
# Index(['Unnamed: 0', 'IdentificacaoParlamentar.CodigoParlamentar',
#        'IdentificacaoParlamentar.NomeParlamentar',
#        'IdentificacaoParlamentar.NomeCompletoParlamentar',
#        'IdentificacaoParlamentar.SexoParlamentar',
#        'IdentificacaoParlamentar.SiglaPartidoParlamentar',
#        'Mandatos.Mandato.CodigoMandato', 'Mandatos.Mandato.UfParlamentar',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataFim',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.NumeroLegislatura',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.DataInicio',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.DataFim',
#        'Mandatos.Mandato.DescricaoParticipacao',
#        'Mandatos.Mandato.Titular.DescricaoParticipacao',
#        'Mandatos.Mandato.Titular.CodigoParlamentar',
#        'Mandatos.Mandato.Titular.NomeParlamentar',
#        'Mandatos.Mandato.Suplentes.Suplente.DescricaoParticipacao',
#        'Mandatos.Mandato.Suplentes.Suplente.CodigoParlamentar',
#        'Mandatos.Mandato.Suplentes.Suplente.NomeParlamentar',
#        'Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio',
#        'Mandatos.Mandato.Exercicios.Exercicio.DataInicio',
#        'Mandatos.Mandato.Exercicios.Exercicio.DataFim',
#        'Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Unnamed: 0       id  tipoDocumento   ano  mes   nomeSenador  \
# 0           0  2002759              3  2015    2  ACIR GURGACZ
# 1           1  2001145              1  2015    2  ACIR GURGACZ
# 2           2  2005025              1  2015    2  ACIR GURGACZ
# 3           3  2001149              1  2015    2  ACIR GURGACZ
# 4           4  2001147              1  2015    2  ACIR GURGACZ
#
#                                          tipoDespesa         cpfCnpj  \
# 0  Aluguel de imóveis para escritório político, c...       494802863
# 1                Divulgação da atividade parlamentar   2147085000160
# 2                Divulgação da atividade parlamentar  84721745000130
# 3  Locomoção, hospedagem, alimentação, combustíve...  34274233009746
# 4  Locomoção, hospedagem, alimentação, combustíve...  34274233009746
#
#                                        fornecedor  documento       data  \
# 0                   GILBERTO PISELO DO NASCIMENTO     002/15 2015-02-25
# 1  ASSOCIAÇÃO COMUNITÁRIA JIPARANAENSE - ASCOJIPA        339 2015-02-02
# 2                             O.F. CALADO EDIÇÕES     000277 2015-02-25
# 3                                   VIBRA ENERGIA  000502038 2015-02-10
# 4                                   VIBRA ENERGIA  000502045 2015-02-10
#
#                                         detalhamento  valorReembolsado
# 0  Despesa com pagamento de aluguel de imóvel uti...           6000.00
# 1                Divulgação da atividade parlamentar            300.00
# 2  Despesa com divulgação da atividade parlamenta...           2000.00
# 3  Despesa com pagamento de combustível para abas...           1728.80
# 4  Despesa com combustível para abastecimento de ...           2271.58

# %%
df.tail(5)
# Out:
#         Unnamed: 0       id  tipoDocumento   ano  mes       nomeSenador  \
# 173594      173594  2191398              6  2022   12  ZEQUINHA MARINHO
# 173595      173595  2192272              6  2022   12  ZEQUINHA MARINHO
# 173596      173596  2192274              6  2022   12  ZEQUINHA MARINHO
# 173597      173597  2192244              6  2022   12  ZEQUINHA MARINHO
# 173598      173598  2193622              6  2022   12  ZEQUINHA MARINHO
#
#                                               tipoDespesa         cpfCnpj  \
# 173594  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
# 173595  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
# 173596  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
# 173597  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
# 173598  Passagens aéreas, aquáticas e terrestres nacio...  22052777000132
#
#            fornecedor documento       data  \
# 173594  Exceller Tour    WIXHAI 2022-12-06
# 173595  Exceller Tour    WITOLM 2022-12-09
# 173596  Exceller Tour    THPKVQ 2022-12-20
# 173597  Exceller Tour    QNN9HX 2022-12-21
# 173598  Exceller Tour    WMQWBX 2022-12-30
#
#                                              detalhamento  valorReembolsado
# 173594  Companhia Aérea: LATAM, Localizador: WIXHAI. P...           2893.04
# 173595  Companhia Aérea: GOL, Localizador: WITOLM. Pas...           1180.19
# 173596  Companhia Aérea: TAM, Localizador: THPKVQ. Pas...           2671.90
# 173597  Companhia Aérea: AZUL, Localizador: QNN9HX. Pa...           1334.31
# 173598  Companhia Aérea: TAM, Localizador: WMQWBX. Pas...           2250.72

# %% [markdown]
# Analisando as duas bases, podemos integrar elas com as informações de **Nome do Parlamentar** e **Numero Legislatura**.
#
# Já colocamos o **Nome do Parlamentar** de cada base com as mesmas caracteristicas, falta criar uma coluna **Numero Legislatura** na base DF.

# %%
# Criação da Coluna Numero Legislatura referente ao gasto na base DF

df['numLegistlatura'] = ''

index_55 = df[(df['data'] >= '2015-02-01') & (df['data'] <= '2019-01-31')].index

index_56 = df[(df['data'] >= '2019-02-01') & (df['data'] <= '2023-01-31')].index

df.loc[index_55,'numLegistlatura'] = '55'

df.loc[index_56,'numLegistlatura'] = '56'

# %%
#  Merge entre as bases DF e DF_SENADORES
df_merged = df.merge(df_senadores, left_on=['nomeSenador'],
                       right_on=['IdentificacaoParlamentar.NomeParlamentar'],
                       how = 'left')

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173599 entries, 0 to 173598
# Data columns (total 39 columns):
#  #   Column                                                           Non-Null Count   Dtype
# ---  ------                                                           --------------   -----
#  0   Unnamed: 0_x                                                     173599 non-null  int64
#  1   id                                                               173599 non-null  int64
#  2   tipoDocumento                                                    173599 non-null  int64
#  3   ano                                                              173599 non-null  int64
#  4   mes                                                              173599 non-null  int64
#  5   nomeSenador                                                      173599 non-null  object
#  6   tipoDespesa                                                      173599 non-null  object
#  7   cpfCnpj                                                          173599 non-null  int64
#  8   fornecedor                                                       173599 non-null  object
#  9   documento                                                        162007 non-null  object
#  10  data                                                             173599 non-null  datetime64[ns]
#  11  detalhamento                                                     121676 non-null  object
#  12  valorReembolsado                                                 173599 non-null  float64
#  13  numLegistlatura                                                  173599 non-null  object
#  14  Unnamed: 0_y                                                     167365 non-null  float64
#  15  IdentificacaoParlamentar.CodigoParlamentar                       167365 non-null  float64
#  16  IdentificacaoParlamentar.NomeParlamentar                         167365 non-null  object
#  17  IdentificacaoParlamentar.NomeCompletoParlamentar                 167365 non-null  object
#  18  IdentificacaoParlamentar.SexoParlamentar                         167365 non-null  object
#  19  IdentificacaoParlamentar.SiglaPartidoParlamentar                 166242 non-null  object
#  20  Mandatos.Mandato.CodigoMandato                                   150126 non-null  float64
#  21  Mandatos.Mandato.UfParlamentar                                   150126 non-null  object
#  22  Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura  150126 non-null  float64
#  23  Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio         150126 non-null  datetime64[ns]
#  24  Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataFim            150126 non-null  datetime64[ns]
#  25  Mandatos.Mandato.SegundaLegislaturaDoMandato.NumeroLegislatura   150126 non-null  float64
#  26  Mandatos.Mandato.SegundaLegislaturaDoMandato.DataInicio          150126 non-null  datetime64[ns]
#  27  Mandatos.Mandato.SegundaLegislaturaDoMandato.DataFim             150126 non-null  datetime64[ns]
#  28  Mandatos.Mandato.DescricaoParticipacao                           150126 non-null  object
#  29  Mandatos.Mandato.Titular.DescricaoParticipacao                   19704 non-null   object
#  30  Mandatos.Mandato.Titular.CodigoParlamentar                       19704 non-null   float64
#  31  Mandatos.Mandato.Titular.NomeParlamentar                         19704 non-null   object
#  32  Mandatos.Mandato.Suplentes.Suplente.DescricaoParticipacao        19704 non-null   object
#  33  Mandatos.Mandato.Suplentes.Suplente.CodigoParlamentar            19704 non-null   float64
#  34  Mandatos.Mandato.Suplentes.Suplente.NomeParlamentar              19704 non-null   object
#  35  Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio            95385 non-null   float64
#  36  Mandatos.Mandato.Exercicios.Exercicio.DataInicio                 95385 non-null   datetime64[ns]
#  37  Mandatos.Mandato.Exercicios.Exercicio.DataFim                    69906 non-null   datetime64[ns]
#  38  Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento  69906 non-null   object
# dtypes: datetime64[ns](7), float64(9), int64(6), object(17)
# memory usage: 53.0+ MB

# %%
#  Filtro dos registros de gastos que não teve o merge desejado
df_nan = df_merged[df_merged['IdentificacaoParlamentar.CodigoParlamentar'].isna()]

# %%
df_nan['nomeSenador'].unique()
# Out:
# array(['ALFREDO NASCIMENTO', 'ANA RITA', 'ANÍBAL DINIZ',
#        'ANTÔNIO CARLOS VALADARES', 'CASILDO MALDANER', 'CÍCERO LUCENA',
#        'CYRO MIRANDA', 'DELCIDIO DO AMARAL', 'EDUARDO SUPLICY',
#        'EPITÁCIO CAFETEIRA', 'INÁCIO ARRUDA', 'IVONETE DANTAS',
#        'JOÃO DURVAL', 'JOÃO VICENTE CLAUDINO', 'MÁRIO COUTO',
#        'MARCO ANTÔNIO COSTA', 'PEDRO SIMON', 'RUBEN FIGUEIRÓ',
#        'SODRÉ SANTORO', 'ZEZÉ PERRELLA', 'PEDRO CHAVES DOS SANTOS FILHO',
#        'JEAN PAUL PRATES', 'WEVERTON ROCHA',
#        'MARIA ELIZA DE AGUIAR E SILVA', 'SAMUEL ARAUJO'], dtype=object)

# %%
df_nan['valorReembolsado'].sum()
# Out:
# 7302758.790000001

# %%
#  prova que existe valores que não estão batendo.
df_senadores[df_senadores['IdentificacaoParlamentar.NomeParlamentar'].isin(df_nan['nomeSenador'].unique())]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, IdentificacaoParlamentar.CodigoParlamentar, IdentificacaoParlamentar.NomeParlamentar, IdentificacaoParlamentar.NomeCompletoParlamentar, IdentificacaoParlamentar.SexoParlamentar, IdentificacaoParlamentar.SiglaPartidoParlamentar, Mandatos.Mandato.CodigoMandato, Mandatos.Mandato.UfParlamentar, Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura, Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio, Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataFim, Mandatos.Mandato.SegundaLegislaturaDoMandato.NumeroLegislatura, Mandatos.Mandato.SegundaLegislaturaDoMandato.DataInicio, Mandatos.Mandato.SegundaLegislaturaDoMandato.DataFim, Mandatos.Mandato.DescricaoParticipacao, Mandatos.Mandato.Titular.DescricaoParticipacao, Mandatos.Mandato.Titular.CodigoParlamentar, Mandatos.Mandato.Titular.NomeParlamentar, Mandatos.Mandato.Suplentes.Suplente.DescricaoParticipacao, Mandatos.Mandato.Suplentes.Suplente.CodigoParlamentar, Mandatos.Mandato.Suplentes.Suplente.NomeParlamentar, Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio, Mandatos.Mandato.Exercicios.Exercicio.DataInicio, Mandatos.Mandato.Exercicios.Exercicio.DataFim, Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento]
# Index: []
#
# [0 rows x 25 columns]

# %%
df_senadores['IdentificacaoParlamentar.NomeParlamentar'].unique()
# Out:
# array(['ABEL REBOUÇAS', 'ABIANCY CADOSO ROSA', 'ACIR GURGACZ',
#        'ADILSON GOMES', 'ADILSON SILVA DOS SANTOS', 'AFONSO PARENTE',
#        'AGIMIRO DIAS DA COSTA', 'AIRTON SANDOVAL', 'ALBERTO DAVID',
#        'ALESSANDRO VIEIRA', 'ALEXANDRE SILVEIRA', 'ALFREDO COTAIT NETO',
#        'ALISSON TAVEIRA', 'ALOYSIO NUNES FERREIRA', 'ALVARO DIAS',
#        'ALZENIR PORTO', 'ALZIRA FERREIRA BARROS', 'ANA AMÉLIA',
#        'ANA MARIA', 'ANA PAULA TONGO', 'ANDRE FILIPE',
#        'ANDRELINA BARBOSA DA CUNHA', 'ANGELO CORONEL',
#        'ANTONIO ANASTASIA', 'ANTONIO CARLOS RODRIGUES',
#        'ANTONIO CARLOS VALADARES', 'ANTÔNIO MARCOS GAVAZZONI',
#        'ANTÔNIO MILTON PESSOA FALCÃO FILHO', 'ARISTAVORA DE SOUZA SANTOS',
#        'ARLINDO SILVA', 'ARMANDO JOSÉ DE OLIVEIRA', 'ARMANDO MONTEIRO',
#        'AROLDE DE OLIVEIRA', 'ASTRONAUTA MARCOS PONTES',
#        'ATAÍDES OLIVEIRA', 'ATHOS DE ALMEIDA LOPES', 'ATILIO FRANCISCO',
#        'AYRES MARCHETTI', 'AÉCIO NEVES', 'BEBETO', 'BENE CAMACHO',
#        'BENEDITO DE LIRA', 'BENJAMIN BEZE JUNIOR', 'BENTO',
#        'BETO MARTINS', 'BETO POSSAMAI', 'BISPO JOSÉ', 'BLAIRO MAGGI',
#        'CARLOS ALBERTO', 'CARLOS AUGUSTO COSTA', 'CARLOS FÁVARO',
#        'CARLOS MILTON MORAIS', 'CARLOS PORTINHO', 'CARLOS VIANA',
#        'CASTELLAR GUIMARÃES NETO', 'CELSO DAL LAGO RODRIGUES',
#        'CESAR ANTONIO DE SOUZA', 'CHAMON', 'CHICO RODRIGUES',
#        'CHIQUINHO FEITOSA', 'CHRISTOPHER GOULART', 'CID GOMES',
#        'CIDINHO SANTOS', 'CIRO NOGUEIRA', 'CLEONICE BACK',
#        'CLERIE FABIANA', 'CLOVIS FECURY', 'CLÉCIO LUIS VILHENA VIEIRA',
#        'CONFÚCIO MOURA', 'CORONEL MARGARIDA', 'CRISTOVAM BUARQUE',
#        'CUNHA LIMA', 'CÁSSIO CUNHA LIMA', 'CÂNDIDA FARIAS',
#        'DALIRIO BEBER', 'DANIELLA RIBEIRO', 'DANILO MARTINS DE OLIVEIRA',
#        'DANNY FABRICIO', 'DAVI ALCOLUMBRE', 'DAVIDSON MAGALHÃES', 'DECA',
#        'DELCÍDIO DO AMARAL', 'DEMÓSTENES TORRES', 'DENISE DOS SANTOS',
#        'DIEGO TAVARES', 'DONIZETI NOGUEIRA', 'DOUGLAS CINTRA',
#        'DR. GUIMARÃES', 'DR. HELDER CAVALCANTE', 'DR. SAMUEL ARAÚJO',
#        'DRA. EUDÓCIA', 'DRICA DE LUCENA', 'DÁRIO BERGER', 'EDISON LOBÃO',
#        'EDIVALDO EDILSON PANTOJA DA SILVA', 'EDUARDO AMORIM',
#        'EDUARDO BRAGA', 'EDUARDO GIRÃO', 'EDUARDO GOMES', 'EDUARDO LOPES',
#        'EDUARDO VELLOSO', 'ELADIO CARNEIRO', 'ELAINE MATOZINHOS RIBEIRO',
#        'ELBER BATALHA', 'ELIANE NOGUEIRA', 'ELIANE RODRIGUES',
#        'ELIZIANE GAMA', 'ELMANO FÉRRER', 'ELMIRO ALVES DO NASCIMENTO',
#        'EMIR SIMÃO SADER', 'ENFERMEIRA ROBERTA',
#        'ENIVALDO EUZÉBIO DOS ANJOS', 'ESPERIDIÃO AMIN',
#        'EUNÍCIO OLIVEIRA', 'FABIANO CONTARATO', 'FABIO GARCIA',
#        'FADI FARAJ', 'FERNANDO BEZERRA COELHO', 'FERNANDO CARVALHO',
#        'FERNANDO CARVALHO LAGE', 'FERNANDO COLLOR', 'FERNANDO DUEIRE',
#        'FERNANDO FAÇANHA', 'FERNANDO RIBEIRO', 'FLAVIO VICENTE', 'FLEURY',
#        'FLEXA RIBEIRO', 'FLÁVIO ARNS', 'FLÁVIO BOLSONARO',
#        'FRANCISCO GARCIA', 'FRANCISCO SIMEÃO RODRIGUES NETO',
#        'FRANCISCO WILSON RIBEIRO', 'FÁBIO LUIZ ARAÚJO LOPES DE FARIAS',
#        'FÁTIMA BEZERRA', 'FÉLIX URANO GAMA DE SOUZA',
#        'GABRIEL MAIA GELPKE', 'GARIBALDI ALVES FILHO', 'GEOVANI BORGES',
#        'GERALDO ALTHOFF', 'GIL PARAIBANO', 'GILBERTO CORAZZA',
#        'GILBERTO PISELO', 'GILVAM BORGES', 'GINO JOSE FERREIRA',
#        'GIORDANO', 'GIVAGO TENÓRIO', 'GLADSON CAMELI', 'GLEISI HOFFMANN',
#        'GUARACY SILVEIRA', 'HELENILSON PONTES', 'HENRIQUE ARRUDA',
#        'HUMBERTO COSTA', 'HÉLIO JOSÉ', 'IONE GUIMARÃES', 'IRAJÁ',
#        'IRENEU ORTH', 'ITAMAR FRANCO', 'IVANCI MAGNO', 'IVANI BOSCOLO',
#        'IVETE DA SILVEIRA', 'IVO CASSOL', 'IVONETE NASCIMENTO',
#        'IZALCI LUCAS', 'JACIRA SOUZA', 'JADER BARBALHO', 'JADER MELO',
#        'JANDUHY MAX FREIRE DE ANDRADE', 'JAQUES WAGNER',
#        'JARBAS VASCONCELOS', 'JAYME CAMPOS', 'JEAN-PAUL PRATES',
#        'JOAQUIM FRANCISCO', 'JOEL MALUCELLI', 'JORGE KAJURU',
#        'JORGE MITIDIERI', 'JORGE VIANA', 'JORGE YANAI', 'JORGINHO MELLO',
#        'JOSE NAGIB DA SILVA LIMA', 'JOSIEL', 'JOSÉ AGRIPINO',
#        'JOSÉ ALBERTO WENZEL', 'JOSÉ AMAURI', 'JOSÉ ANTONIO GUIDONI',
#        'JOSÉ ANÍBAL', 'JOSÉ CARLOS VASCONCELLOS', 'JOSÉ CHAGAS',
#        'JOSÉ EDUARDO DUTRA', 'JOSÉ ESTEVES DE LACERDA FILHO',
#        'JOSÉ HAMILTON', 'JOSÉ MARANHÃO', 'JOSÉ MEDEIROS', 'JOSÉ PIMENTEL',
#        'JOSÉ RODRIGUES DA SILVA', 'JOSÉ SERRA', 'JOSÉ DE MACEDO FERREIRA',
#        'JOÃO ALBERTO SOUZA', 'JOÃO BATISTA LEMOS', 'JOÃO CAPIBERIBE',
#        'JOÃO CLAUDINO FERNANDES', 'JOÃO COSTA', 'JOÃO FAUSTINO',
#        'JOÃO RIBEIRO', 'JULIO VENTURA', 'JUÇARA FEITOSA DE OLIVEIRA',
#        'JUÍZA SELMA', 'JÚNIOR SOUTO', 'KAKÁ ANDRADE', 'KÁTIA ABREU',
#        'LAEL VARELLA', 'LASIER MARTINS', 'LAURO ANTONIO', 'LEANY LEMOS',
#        'LEILA BARROS', 'LEONARDO RODRIGUES', 'LINDBERGH FARIAS',
#        'LIRIO ALBINO PARISOTTO', 'LOBÃO FILHO', 'LUCAS BARRETO',
#        'LUCIANA LEÃO MUNIZ', 'LUIS CARLOS HEINZE',
#        'LUIS CARLOS PAES DE CASTRO', 'LUIS CLÁUDIO DA COSTA AVELAR',
#        'LUIS FELIPE BELMONTE', 'LUIS MITOSO', 'LUIZ CARLOS DO CARMO',
#        'LUIZ HENRIQUE', 'LUIZ PASTORE', 'LUÍS GUILHERME GOMES MUSSI',
#        'LÍDICE DA MATA', 'LÚCIA VÂNIA', 'MACAPÁ', 'MAGNO MALTA',
#        'MAILZA GOMES', 'MAJOR ILDOMARIO', 'MAJOR OLIMPIO',
#        'MANOEL ANGELO CHAGAS', 'MANOEL MOTTA', 'MARA GABRILLI',
#        'MARCELO CASTRO', 'MARCELO CRIVELLA', 'MARCIA DO ANGICO',
#        'MARCIO BITTAR', 'MARCONDES GADELHA', 'MARCOS ROGÉRIO',
#        'MARCOS DE SOUZA COSTA', 'MARCOS DO VAL', 'MARGARETH BUZETTI',
#        'MARIA ALICE', 'MARIA ANTONIETA AMORIM DOS SANTOS', 'MARIA ELIZA',
#        'MARIA LUZA DE AQUINO MACHADO', 'MARIA DA TAIÇOCA',
#        'MARIA DAS VITÓRIAS', 'MARIA DE POMPEIA LINS PESSOA',
#        'MARIA DO CARMO ALVES', 'MARINHO CUNHA', 'MARINOR BRITO',
#        'MARIZETE', 'MARQUINHO', 'MARTA MARIA FREIRE DA COSTA',
#        'MARTA SUPLICY', 'MAURO FECURY', 'MECIAS DE JESUS',
#        'MIGUEL BIANGO', 'MIGUEL DIAS DE SOUZA', 'MILTON MERCÊZ',
#        'MOACIR KOHL', 'MÁRCIO BERGONSI TURRA', 'NAILDE PANTA',
#        'NELSINHO TRAD', 'NESTOR DUARTE GUIMARÃES NETO', 'NEY SUASSUNA',
#        'NICIAS RIBEIRO', 'NILDA GONDIM', 'NILSON MOURÃO', 'ODACIR SOARES',
#        'OGARI PACHECO', 'OLNEY RIBEIRO BOTELHO', 'OMAR AZIZ',
#        'ONÉSIMO CRUZ', 'ORIOVISTO GUIMARÃES', 'OTTO ALENCAR',
#        'PABLO SERGIO SOUZA BEZERRA', 'PASTOR AMARILDO', 'PASTOR BEL',
#        'PASTOR GAIA', 'PASTOR IBANES TAVEIRA', 'PASTOR MANOEL ROBERTO',
#        'PASTOR SEVERINO', 'PASTOR VALADARES', 'PATRICIA COSTA',
#        'PAULO ALBUQUERQUE', 'PAULO ANTENOR DE OLIVEIRA', 'PAULO BAUER',
#        'PAULO DAVIM', 'PAULO FRATESCHI', 'PAULO GOUVÊA', 'PAULO MARINHO',
#        'PAULO MATOS', 'PAULO PAIM', 'PAULO PEREIRA FÍUZA FILHO',
#        'PAULO ROCHA', 'PAULO SALAMUNI', 'PEDRO ARTHUR', 'PEDRO CHAVES',
#        'PEDRO FERNANDES', 'PEDRO IRNO TONELLI', 'PEDRO TAQUES',
#        'PINTO ITAMARATY', 'PLINIO DESTRO', 'PLÍNIO VALÉRIO',
#        'PRISCO BEZERRA', 'PROFESSORA BAZÉ', 'RAFAEL TENÓRIO',
#        'RAIMUNDO LIRA', 'RANDOLFE RODRIGUES', 'REDITARIO CASSOL',
#        'REGINA SOUSA', 'REGINETE BISPO', 'REGUFFE', 'RENAN CALHEIROS',
#        'RENATA GUERRA', 'RENILDE BULHÕES', 'RENZO BRAZ',
#        'RICARDO FERRAÇO', 'RICARDO FRANCO', 'ROBERTH BRINGEL',
#        'ROBERTO MUNIZ', 'ROBERTO REQUIÃO', 'ROBERTO ROCHA',
#        'ROBERTO WAGNER MONTEIRO', 'RODOLFO NOGUEIRA', 'RODRIGO CUNHA',
#        'RODRIGO PACHECO', 'RODRIGO ROLLEMBERG', 'RODRIGUES PALMA',
#        'ROGÉRIO CARVALHO', 'ROMERO JUCÁ', 'ROMÁRIO', 'RONALDO CAIADO',
#        'RONALDO LIBARDI', 'ROOSEVELT VITA', 'ROSANA FOERST',
#        'ROSE DE FREITAS', 'ROSÁRIO BEZERRA', 'RUDSON LEITE',
#        'SALOMÃO ALCOLUMBRE JÚNIOR', 'SANDER FRAXE SALOMAO',
#        'SANDRA BRAGA', 'SANNY JAPIASSÚ DOS SANTOS', 'SARGENTO REGINALDO',
#        'SCHARIFF MOYSES', 'SERGIO SOUZA', 'SEVERINO ARAUJO',
#        'SEVERINO LEÃO', 'SILVANIA BARBOSA',
#        'SILVIA NASCIMENTO CARDOSO DOS SANTOS CERQUEIRA', 'SIMONE TEBET',
#        'SIQUEIRA CAMPOS', 'SORAYA THRONICKE', 'STYVENSON VALENTIM',
#        'SUELY PEREIRA', 'SUELY SANTIAGO', 'SÉRGIO NOVAIS',
#        'SÉRGIO PETECÃO', 'SÉRGIO DE CASTRO', 'TASSO JEREISSATI',
#        'TELMÁRIO MOTA', 'TERCILIANO GOMES', 'THEODORICO BEZERRA NETTO',
#        'THIERES PINTO', 'TILDEN SANTIAGO', 'TOMÁS CORREIA',
#        'TÂNIA CRISTINA MAGALHÃES BASTOS E SILVA', 'UBIRACI PICANÇO',
#        'VALDIR GANZER', 'VALDIR RAUPP',
#        'VALÉRIO DJALMA CAVALCANTI MARINHO', 'VANDERLAN CARDOSO',
#        'VANESSA GRAZZIOTIN', 'VENEZIANO VITAL DO RÊGO',
#        'VERIDIANA MARIA TONINI', 'VICENTINHO ALVES', 'VILSON BASSO',
#        'VIRGINIO DE CARVALHO', 'VITAL DO RÊGO', 'VIVALDO BARBOSA',
#        'WALDEMAR OLIVEIRA', 'WALDEMIR CATANHO DE SENA JÚNIOR',
#        'WALDEMIR MOKA', 'WALTER PINHEIRO', 'WELLINGTON DIAS',
#        'WELLINGTON FAGUNDES', 'WEVERTON', 'WILDER MORAIS',
#        'WILMAR LACERDA', 'WILSON SANTIAGO', 'WIRLANDE DA LUZ',
#        'ZENAIDE MAIA', 'ZEQUINHA MARINHO', 'ZEZE PERRELLA',
#        'ZONIR FREITAS TETILA', 'ZÉ SANTANA', 'ÂNGELA PORTELA'],
#       dtype=object)

# %%
# rodar a instalação do pacote apenas uma vez
#!pip install unidecode

# %%
# Crie uma função que corrija os nomes para um mesmo padrão nas bases DF e DF_senadores

df_senadores.loc[df_senadores['IdentificacaoParlamentar.NomeParlamentar'] == 'JEAN-PAUL PRATES', 'IdentificacaoParlamentar.NomeParlamentar'] = 'JEAN PAUL PRATES'
df_senadores.loc[df_senadores['IdentificacaoParlamentar.NomeParlamentar'] == 'WEVERTON', 'IdentificacaoParlamentar.NomeParlamentar'] = 'WEVERTON ROCHA'
df_senadores.loc[df_senadores['IdentificacaoParlamentar.NomeParlamentar'] == 'MARIA ELIZA', 'IdentificacaoParlamentar.NomeParlamentar'] = 'MARIA ELIZA DE AGUIAR E SILVA'
df_senadores.loc[df_senadores['IdentificacaoParlamentar.NomeParlamentar'] == 'PEDRO CHAVES', 'IdentificacaoParlamentar.NomeParlamentar'] = 'PEDRO CHAVES DOS SANTOS FILHO'
df_senadores.loc[df_senadores['IdentificacaoParlamentar.NomeParlamentar'] == 'DR. SAMUEL ARAUJO', 'IdentificacaoParlamentar.NomeParlamentar'] = 'SAMUEL ARAUJO'

from unidecode import unidecode
df['nomeSenador'] = df['nomeSenador'].apply(unidecode)
df_senadores['IdentificacaoParlamentar.NomeParlamentar'] = df_senadores['IdentificacaoParlamentar.NomeParlamentar'].apply(unidecode)

df_merged = df.merge(df_senadores, left_on=['nomeSenador'],
                       right_on=['IdentificacaoParlamentar.NomeParlamentar'],
                       how = 'left')

df = df_merged

# %% [markdown]
# Considerações da Analise Descritiva para próxima etapa de Análise sob a Teoria Distribuição Normal:
#
# Ações Realizadas:
# 1. Coluna Date está em string, transformar para datetime.
# 2. Existe Números Negativos Na Coluna valorReembolsado, verificar tratativa.
# 3. Apagar Colunas desnecessárias
# 4. Ajustar Nome Parlamentar
# 5. Merge das Tabelas df e df_senadores
#
# Ações Futuras:
# 1. Verificar valores nulos presentes nas colunas documento e detalhamento
# 2. Verificar Comportamento da coluna valorReembolsado
# 3. Valores nulos presentes nas colunas documento e detalhamento não são pertinentes para eliminação ou de inserção de novos valores.

# %% [markdown]
# ## Análise sob a Teoria Distribuição Normal

# %%
sns.histplot(df["valorReembolsado"])
# Out:
# <Axes: xlabel='valorReembolsado', ylabel='Count'>

# %%
# Como resolver essa visulização acima? vemos a existência de outliers estão "sujando" o histograma.

df_filter = df[df["valorReembolsado"] < df["valorReembolsado"].quantile(.95)]

sns.histplot(df_filter['valorReembolsado'])
# Out:
# <Axes: xlabel='valorReembolsado', ylabel='Count'>

# %%
# Realize o .describe() desses dados filtrados.
df_filter[['valorReembolsado']].describe()
# Out:
#        valorReembolsado
# count     165743.000000
# mean         712.476670
# std          870.153268
# min            0.010000
# 25%          126.780000
# 50%          313.570000
# 75%         1000.000000
# max         4496.030000

# %%
# Vamos Entender os outliers? Possivelmente são informações importantes para simplemente serem descartadas. 
# Realize o .describe() desses dados.

df_outliers = df[df["valorReembolsado"] >= df["valorReembolsado"].quantile(.95)]

df_outliers[['valorReembolsado']].describe()
# Out:
#        valorReembolsado
# count       8901.000000
# mean        9354.744242
# std         8832.424706
# min         4500.000000
# 25%         5363.020000
# 50%         6800.000000
# 75%        10000.000000
# max       270000.000000

# %%
sns.histplot(df_outliers[['valorReembolsado']])
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Considerações da Analise Descritiva para próxima etapa de Análise sob a Tratamento de Valores Nulos e Valores Atípicos:
#
# Ações Realizadas:
# 1. Verificar valores nulos presentes nas colunas documento e detalhamento
# 2. Verificar Comportamento da coluna valorReembolsado
# 3. Valores nulos presentes nas colunas documento e detalhamento não são pertinentes para eliminação ou de inserção de novos valores.
#
# Ações Futuras:
# 1. Validar valores nulos da Col detalhamento
# 2. Tratativa para Valores Outliers

# %% [markdown]
# ## Tratamento de Valores Nulos e Valores Atípicos

# %%
10000 / df.valorReembolsado.sum()
# Out:
# 4.966362843580924e-05

# %%
df[df['detalhamento'].isna()]
# Out:
#         Unnamed: 0_x       id  tipoDocumento   ano  mes         nomeSenador  \
# 68                68  2000857              4  2015    1        ACIR GURGACZ
# 211              211  2000792              3  2015    1  ALFREDO NASCIMENTO
# 212              212  2000796              4  2015    1  ALFREDO NASCIMENTO
# 902              902  2011576              1  2015    6         ALVARO DIAS
# 927              927  2017063              4  2015    8         ALVARO DIAS
# ...              ...      ...            ...   ...  ...                 ...
# 174633        173588  2192243              2  2022   12    ZEQUINHA MARINHO
# 174634        173589  2192248              2  2022   12    ZEQUINHA MARINHO
# 174635        173590  2192242              2  2022   12    ZEQUINHA MARINHO
# 174636        173591  2192250              2  2022   12    ZEQUINHA MARINHO
# 174637        173592  2192249              2  2022   12    ZEQUINHA MARINHO
#
#                                               tipoDespesa         cpfCnpj  \
# 68      Aluguel de imóveis para escritório político, c...   5914650000166
# 211     Aluguel de imóveis para escritório político, c...      2321157100
# 212     Aluguel de imóveis para escritório político, c...    108786000165
# 902     Locomoção, hospedagem, alimentação, combustíve...   7686368000102
# 927     Locomoção, hospedagem, alimentação, combustíve...  16978175000108
# ...                                                   ...             ...
# 174633  Locomoção, hospedagem, alimentação, combustíve...  19614800000120
# 174634  Locomoção, hospedagem, alimentação, combustíve...  34307872000119
# 174635  Locomoção, hospedagem, alimentação, combustíve...   9631455000180
# 174636  Locomoção, hospedagem, alimentação, combustíve...   2280133004262
# 174637  Locomoção, hospedagem, alimentação, combustíve...  28298039000156
#
#                                                fornecedor    documento  ...  \
# 68                                               ENERGISA       647777  ...
# 211                         Gilberto Assunção de Oliveira          NaN  ...
# 212                                                   Net          NaN  ...
# 902                                        WTC - Sheraton    002270572  ...
# 927                               Ádria Viagens e Turismo  FT00005287d  ...
# ...                                                   ...          ...  ...
# 174633  AUTO POSTO INDEPENDENCIA COMERCIO DE COMBUSTÍV...       685963  ...
# 174634               J M F COMÉRCIO DE COMBUSTIVEIS LTDA.        21169  ...
# 174635    POSTO CAMILA VAREJISTA DE COMBUSTÍVEL LTDA. EPP      1446149  ...
# 174636                                  POSTO ICCAR LTDA.       197440  ...
# 174637                            REDE POSTO POMBAL LTDA.    000221800  ...
#
#        Mandatos.Mandato.Titular.DescricaoParticipacao  \
# 68                                                NaN
# 211                                               NaN
# 212                                               NaN
# 902                                               NaN
# 927                                               NaN
# ...                                               ...
# 174633                                            NaN
# 174634                                            NaN
# 174635                                            NaN
# 174636                                            NaN
# 174637                                            NaN
#
#        Mandatos.Mandato.Titular.CodigoParlamentar  \
# 68                                            NaN
# 211                                           NaN
# 212                                           NaN
# 902                                           NaN
# 927                                           NaN
# ...                                           ...
# 174633                                        NaN
# 174634                                        NaN
# 174635                                        NaN
# 174636                                        NaN
# 174637                                        NaN
#
#         Mandatos.Mandato.Titular.NomeParlamentar  \
# 68                                           NaN
# 211                                          NaN
# 212                                          NaN
# 902                                          NaN
# 927                                          NaN
# ...                                          ...
# 174633                                       NaN
# 174634                                       NaN
# 174635                                       NaN
# 174636                                       NaN
# 174637                                       NaN
#
#        Mandatos.Mandato.Suplentes.Suplente.DescricaoParticipacao  \
# 68                                                    NaN
# 211                                                   NaN
# 212                                                   NaN
# 902                                                   NaN
# 927                                                   NaN
# ...                                                   ...
# 174633                                                NaN
# 174634                                                NaN
# 174635                                                NaN
# 174636                                                NaN
# 174637                                                NaN
#
#         Mandatos.Mandato.Suplentes.Suplente.CodigoParlamentar  \
# 68                                                    NaN
# 211                                                   NaN
# 212                                                   NaN
# 902                                                   NaN
# 927                                                   NaN
# ...                                                   ...
# 174633                                                NaN
# 174634                                                NaN
# 174635                                                NaN
# 174636                                                NaN
# 174637                                                NaN
#
#         Mandatos.Mandato.Suplentes.Suplente.NomeParlamentar  \
# 68                                                    NaN
# 211                                                   NaN
# 212                                                   NaN
# 902                                                   NaN
# 927                                                   NaN
# ...                                                   ...
# 174633                                                NaN
# 174634                                                NaN
# 174635                                                NaN
# 174636                                                NaN
# 174637                                                NaN
#
#        Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio  \
# 68                                                    NaN
# 211                                                   NaN
# 212                                                   NaN
# 902                                                2755.0
# 927                                                2755.0
# ...                                                   ...
# 174633                                             2916.0
# 174634                                             2916.0
# 174635                                             2916.0
# 174636                                             2916.0
# 174637                                             2916.0
#
#        Mandatos.Mandato.Exercicios.Exercicio.DataInicio  \
# 68                                                  NaT
# 211                                                 NaT
# 212                                                 NaT
# 902                                          2015-02-01
# 927                                          2015-02-01
# ...                                                 ...
# 174633                                       2019-02-01
# 174634                                       2019-02-01
# 174635                                       2019-02-01
# 174636                                       2019-02-01
# 174637                                       2019-02-01
#
#        Mandatos.Mandato.Exercicios.Exercicio.DataFim  \
# 68                                               NaT
# 211                                              NaT
# 212                                              NaT
# 902                                       2023-01-31
# 927                                       2023-01-31
# ...                                              ...
# 174633                                           NaT
# 174634                                           NaT
# 174635                                           NaT
# 174636                                           NaT
# 174637                                           NaT
#
#        Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento
# 68                                                    NaN
# 211                                                   NaN
# 212                                                   NaN
# 902                                    Término do mandato
# 927                                    Término do mandato
# ...                                                   ...
# 174633                                                NaN
# 174634                                                NaN
# 174635                                                NaN
# 174636                                                NaN
# 174637                                                NaN
#
# [51972 rows x 39 columns]

# %%
# Calcule qual é a % de valores nulos na col detalhamento
len(df[df['detalhamento'].isna()]) / len(df) * 100
# Out:
# 29.758823664139623

# %% [markdown]
# **é pertinente apagar ou alterar os valores nulos e outliers da base?**

# %% [markdown]
# Considerações da Analise Descritiva para próxima etapa de Análise sob a Tratamento de Valores Nulos e Valores Atípicos:
#
# Ações Realizadas:
# 1. Validar valores nulos da Col detalhamento
# 2. Tratativa para Valores Outliers
#
# Ações Futuras:
# 1. Extrair insights por visualização de dados

# %% [markdown]
# ## Visualização de Dados

# %%
# Filtro para Retirar Senadores que exerceram o mandato menos que 1 ano.
cod_senadores_menos_365dias = df_senadores[(~df_senadores['Mandatos.Mandato.Exercicios.Exercicio.DataFim'].isna()) & 
                                           (df_senadores['Mandatos.Mandato.DescricaoParticipacao'] != 'Titular') &
                                           ((df_senadores['Mandatos.Mandato.Exercicios.Exercicio.DataFim'] - df_senadores['Mandatos.Mandato.Exercicios.Exercicio.DataInicio'] ).dt.days < 365)
                                          ]['IdentificacaoParlamentar.CodigoParlamentar'].values

# %%
df_senadores_mais_365dias = df[~df['IdentificacaoParlamentar.CodigoParlamentar'].isin(cod_senadores_menos_365dias)]

# %%
# Vamos ver quem são os 5 senadores mais gastões ou econômicos do senado? Utilize Tabelas para representar os metadados.

group_senador_valorReembolsado = df[['nomeSenador','IdentificacaoParlamentar.CodigoParlamentar','valorReembolsado']].groupby(['nomeSenador','IdentificacaoParlamentar.CodigoParlamentar']).sum(['valorReembolsado']).sort_values(by='valorReembolsado',ascending=False).reset_index()

group_senador_valorReembolsado = group_senador_valorReembolsado[~group_senador_valorReembolsado['IdentificacaoParlamentar.CodigoParlamentar'].isin(cod_senadores_menos_365dias)]

group_senador_valorReembolsado.head(5)
# Out:
#        nomeSenador  IdentificacaoParlamentar.CodigoParlamentar  \
# 0      PAULO ROCHA                                       374.0
# 1    TELMARIO MOTA                                      5535.0
# 2  DAVI ALCOLUMBRE                                      3830.0
# 3        OMAR AZIZ                                      5525.0
# 4   SERGIO PETECAO                                      4560.0
#
#    valorReembolsado
# 0        3602758.48
# 1        3552478.33
# 2        3407374.58
# 3        3367994.47
# 4        3324759.91

# %%
group_senador_valorReembolsado.tail(5)
# Out:
#               nomeSenador  IdentificacaoParlamentar.CodigoParlamentar  \
# 168         EDUARDO GIRAO                                      5976.0
# 171          LUIZ PASTORE                                       151.0
# 173  VIRGINIO DE CARVALHO                                      4786.0
# 176       FERNANDO DUEIRE                                      5917.0
# 181          LEILA BARROS                                      5979.0
#
#      valorReembolsado
# 168          65211.79
# 171          60406.19
# 173          52139.05
# 176          50109.17
# 181          10567.64

# %% [markdown]
# Temos um problema, temos valores baixos pelo fato que normalmente senadores eleitos são substituidos temporariamente por N motivos por seus respectivos suplentes, nesse caso temos que classificar em **senadores titulares** e **senadores suplentes**.
#
# Precisamos melhorar nossa base de dados, portanto, devemos procurar mais dados abertos sobre o mandato dos senadores. Para isso temos que voltar na etapa, fazer carregamento e enriquecimento de dados na primeira etapa.
#
# Consulte as api neste [link](https://legis.senado.leg.br/dadosabertos/docs/resource_ListaSenadorService.html)

# %%
# Qual são os 5 partidos Mais Gastões ou econômicos do senado? 
# Utilize Tabelas para representar os metadados.

group_partido_valorReembolsado = df_senadores_mais_365dias

group_partido_valorReembolsado = df[['IdentificacaoParlamentar.SiglaPartidoParlamentar','valorReembolsado']].groupby(['IdentificacaoParlamentar.SiglaPartidoParlamentar']).sum(['valorReembolsado']).sort_values(by='valorReembolsado',ascending=False).reset_index()

group_partido_valorReembolsado.head(5)
# Out:
#   IdentificacaoParlamentar.SiglaPartidoParlamentar  valorReembolsado
# 0                                              MDB       34891872.90
# 1                                              PSD       25677994.45
# 2                                               PT       24295484.49
# 3                                               PP       19264409.34
# 4                                             PSDB       18432619.56

# %%
group_partido_valorReembolsado.tail(5)
# Out:
#    IdentificacaoParlamentar.SiglaPartidoParlamentar  valorReembolsado
# 17                                        S/Partido         547091.39
# 18                                        CIDADANIA         229495.97
# 19                                             PRTB         153741.45
# 20                                               PV         123015.14
# 21                                             NOVO          65211.79

# %%
# Faça um comparativo entre os mandatos de 2019 - 2022 e 2015 - 2018, qual foi o custo total para ambos mandatos por ano? 
# Utilize Gráfico de linha para representar os metadados.

# %%
# Qual são os 5 tipos de despesa mais utilizadas por senadores? 
# Desfio: Some o restante dos tipos de despesas em uma barra "Outros"? 
# Utilize Gráfico de Barra para representar os metadados.

group_despesa_quantidade = df_senadores_mais_365dias

group_despesa_quantidade = group_despesa_quantidade[['id','tipoDespesa']].groupby(['tipoDespesa']).count().sort_values(by='id',ascending=False).reset_index()

group_despesa_quantidade['id'] = group_despesa_quantidade.id * 0.001

group_despesa_quantidade['tipoDespesa'] = group_despesa_quantidade['tipoDespesa'].apply(lambda row: '\n'.join(wrap(row, 30)))

plt.figure(figsize=(10,11))
ax = sns.barplot(data=group_despesa_quantidade, x="id", y="tipoDespesa");
ax.set(xlabel=None, ylabel=None)
ax.set(xticklabels=[])  
ax.bar_label(ax.containers[0], fmt='{:.2f} Mil', padding= 5)
ax.set(title='Quatidade de Gastos Reembolsados por Tipo utilizado por Senadores da República entre 2015 e 2022');
sns.despine(left=True, bottom=True)

# %%
# Qual são os 5 tipos de despesa mais gastas por senadores? 
# Utilize Tabelas para representar os metadados.

group_despesa_valorReembolsado = df_senadores_mais_365dias

group_despesa_valorReembolsado = group_despesa_valorReembolsado[['tipoDespesa','valorReembolsado']].groupby(['tipoDespesa']).sum(['valorReembolsado']).sort_values(by='valorReembolsado',ascending=False).reset_index()

group_despesa_valorReembolsado['valorReembolsado'] = group_despesa_valorReembolsado.valorReembolsado * 0.00001

group_despesa_valorReembolsado['tipoDespesa'] = group_despesa_valorReembolsado['tipoDespesa'].apply(lambda row: '\n'.join(wrap(row, 30)))

plt.figure(figsize=(10,11))
ax = sns.barplot(data=group_despesa_valorReembolsado, x="valorReembolsado", y="tipoDespesa");
ax.set(xlabel=None, ylabel=None)
ax.set(xticklabels=[])  
ax.bar_label(ax.containers[0], fmt='{:.2f} Mi', padding= 5)
ax.set(title='Quantia dos Gastos Reembolsados em Reais por Tipo utilizado por Senadores da República entre 2015 e 2022');
sns.despine(left=True, bottom=True)

# %%
group_gasto_valorReembolsado_medio.columns
# Out:
# Index(['Unnamed: 0_x', 'id', 'tipoDocumento', 'ano', 'mes', 'nomeSenador',
#        'tipoDespesa', 'cpfCnpj', 'fornecedor', 'documento', 'data',
#        'detalhamento', 'valorReembolsado', 'numLegistlatura', 'Unnamed: 0_y',
#        'IdentificacaoParlamentar.CodigoParlamentar',
#        'IdentificacaoParlamentar.NomeParlamentar',
#        'IdentificacaoParlamentar.NomeCompletoParlamentar',
#        'IdentificacaoParlamentar.SexoParlamentar',
#        'IdentificacaoParlamentar.SiglaPartidoParlamentar',
#        'Mandatos.Mandato.CodigoMandato', 'Mandatos.Mandato.UfParlamentar',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.NumeroLegislatura',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataInicio',
#        'Mandatos.Mandato.PrimeiraLegislaturaDoMandato.DataFim',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.NumeroLegislatura',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.DataInicio',
#        'Mandatos.Mandato.SegundaLegislaturaDoMandato.DataFim',
#        'Mandatos.Mandato.DescricaoParticipacao',
#        'Mandatos.Mandato.Titular.DescricaoParticipacao',
#        'Mandatos.Mandato.Titular.CodigoParlamentar',
#        'Mandatos.Mandato.Titular.NomeParlamentar',
#        'Mandatos.Mandato.Suplentes.Suplente.DescricaoParticipacao',
#        'Mandatos.Mandato.Suplentes.Suplente.CodigoParlamentar',
#        'Mandatos.Mandato.Suplentes.Suplente.NomeParlamentar',
#        'Mandatos.Mandato.Exercicios.Exercicio.CodigoExercicio',
#        'Mandatos.Mandato.Exercicios.Exercicio.DataInicio',
#        'Mandatos.Mandato.Exercicios.Exercicio.DataFim',
#        'Mandatos.Mandato.Exercicios.Exercicio.DescricaoCausaAfastamento'],
#       dtype='object')

# %%
# Qual é o gasto médio entre Homens e Mulheres? 
# Utilize Tabelas para representar os metadados.

group_gasto_valorReembolsado_medio = df_senadores_mais_365dias

group_gasto_valorReembolsado_medio[['IdentificacaoParlamentar.SexoParlamentar','valorReembolsado']].groupby(['IdentificacaoParlamentar.SexoParlamentar']).mean(['valorReembolsado']).sort_values(by='valorReembolsado',ascending=False).reset_index()
# Out:
#   IdentificacaoParlamentar.SexoParlamentar  valorReembolsado
# 0                                Masculino       1164.733691
# 1                                 Feminino       1051.161605

# %%
group_gasto_valorReembolsado_medio[['IdentificacaoParlamentar.SexoParlamentar','valorReembolsado']].groupby(['IdentificacaoParlamentar.SexoParlamentar']).median(['valorReembolsado']).sort_values(by='valorReembolsado',ascending=False).reset_index()
# Out:
#   IdentificacaoParlamentar.SexoParlamentar  valorReembolsado
# 0                                 Feminino            355.97
# 1                                Masculino            354.03

# %%
df_senador_sexo_legislatura = df[['IdentificacaoParlamentar.SexoParlamentar','numLegistlatura','IdentificacaoParlamentar.CodigoParlamentar']]

# %%
df_senador_sexo_legislatura['IdentificacaoParlamentar.CodigoParlamentar'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[250], line 1
# ----> 1 df_senador_sexo_legislatura['IdentificacaoParlamentar.CodigoParlamentar'].astype(int)
#
# File ~\miniconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File ~\miniconda3\lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File ~\miniconda3\lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\miniconda3\lib\site-packages\pandas\core\dtypes\astype.py:140, in astype_nansafe(arr, dtype, copy, skipna)
#     137     raise TypeError(f"cannot astype a timedelta from [{arr.dtype}] to [{dtype}]")
#     139 elif np.issubdtype(arr.dtype, np.floating) and is_integer_dtype(dtype):
# --> 140     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     142 elif is_object_dtype(arr.dtype):
#     143
#     144     # if we have a datetime/timedelta array of objects
#     145     # then coerce to a proper dtype and recall astype_nansafe
#     147     if is_datetime64_dtype(dtype):
#
# File ~\miniconda3\lib\site-packages\pandas\core\dtypes\astype.py:182, in _astype_float_to_int_nansafe(values, dtype, copy)
#     178 """
#     179 astype with a check preventing converting NaN to an meaningless integer value.
#     180 """
#     181 if not np.isfinite(values).all():
# --> 182     raise IntCastingNaNError(
#     183         "Cannot convert non-finite values (NA or inf) to integer"
#     184     )
#     185 if dtype.kind == "u":
#     186     # GH#45151
#     187     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df_senador_sexo_legislatura['numLegistlatura']
# Out:
# 0         55
# 1         55
# 2         55
# 3         55
# 4         55
#           ..
# 174639    56
# 174640    56
# 174641    56
# 174642    56
# 174643    56
# Name: numLegistlatura, Length: 174644, dtype: object

# %%
str(df_senador_sexo_legislatura['IdentificacaoParlamentar.CodigoParlamentar']) + '-' + df_senador_sexo_legislatura['numLegistlatura']
# Out:
# 0         0         4981.0\n1         4981.0\n2         ...
# 1         0         4981.0\n1         4981.0\n2         ...
# 2         0         4981.0\n1         4981.0\n2         ...
# 3         0         4981.0\n1         4981.0\n2         ...
# 4         0         4981.0\n1         4981.0\n2         ...
#                                 ...
# 174639    0         4981.0\n1         4981.0\n2         ...
# 174640    0         4981.0\n1         4981.0\n2         ...
# 174641    0         4981.0\n1         4981.0\n2         ...
# 174642    0         4981.0\n1         4981.0\n2         ...
# 174643    0         4981.0\n1         4981.0\n2         ...
# Name: numLegistlatura, Length: 174644, dtype: object

# %%
df_senador_sexo_legislatura['CodigoParlamentar_numLegistlatura'] = str(df_senador_sexo_legislatura['IdentificacaoParlamentar.CodigoParlamentar']) + '-' + df_senador_sexo_legislatura['numLegistlatura']
# Out:
# C:\Users\pedroDesktop\AppData\Local\Temp\ipykernel_21488\3762258206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_senador_sexo_legislatura['CodigoParlamentar_numLegistlatura'] = str(df_senador_sexo_legislatura['IdentificacaoParlamentar.CodigoParlamentar']) + '-' + df_senador_sexo_legislatura['numLegistlatura']

# %%
df_senador_sexo_legislatura['CodigoParlamentar_numLegistlatura']
# Out:
# 0         0         4981.0\n1         4981.0\n2         ...
# 1         0         4981.0\n1         4981.0\n2         ...
# 2         0         4981.0\n1         4981.0\n2         ...
# 3         0         4981.0\n1         4981.0\n2         ...
# 4         0         4981.0\n1         4981.0\n2         ...
#                                 ...
# 174639    0         4981.0\n1         4981.0\n2         ...
# 174640    0         4981.0\n1         4981.0\n2         ...
# 174641    0         4981.0\n1         4981.0\n2         ...
# 174642    0         4981.0\n1         4981.0\n2         ...
# 174643    0         4981.0\n1         4981.0\n2         ...
# Name: CodigoParlamentar_numLegistlatura, Length: 174644, dtype: object

# %%
df_senador_sexo_legislatura['CodigoParlamentar_numLegistlatura'].unique()
# Out:
# array(['0         4981.0\n1         4981.0\n2         4981.0\n3         4981.0\n4         4981.0\n           ...  \n174639    3806.0\n174640    3806.0\n174641    3806.0\n174642    3806.0\n174643    3806.0\nName: IdentificacaoParlamentar.CodigoParlamentar, Length: 174644, dtype: float64-55',
#        '0         4981.0\n1         4981.0\n2         4981.0\n3         4981.0\n4         4981.0\n           ...  \n174639    3806.0\n174640    3806.0\n174641    3806.0\n174642    3806.0\n174643    3806.0\nName: IdentificacaoParlamentar.CodigoParlamentar, Length: 174644, dtype: float64-',
#        '0         4981.0\n1         4981.0\n2         4981.0\n3         4981.0\n4         4981.0\n           ...  \n174639    3806.0\n174640    3806.0\n174641    3806.0\n174642    3806.0\n174643    3806.0\nName: IdentificacaoParlamentar.CodigoParlamentar, Length: 174644, dtype: float64-56'],
#       dtype=object)

# %%
# Representividade Feminina aumentou em 2019 - 2022 em comparação a legislatura anteior?
# Utilize Gráfico de pizza para representar os metadados.

df_senador_sexo_legislatura = df[['IdentificacaoParlamentar.SexoParlamentar','numLegistlatura','IdentificacaoParlamentar.CodigoParlamentar']]



df_senadores[['IdentificacaoParlamentar.SexoParlamentar','numLegistlatura','IdentificacaoParlamentar.CodigoParlamentar']].groupby(['IdentificacaoParlamentar.SexoParlamentar','numLegistlatura']).count().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[146], line 4
#       1 # Representividade Feminina aumentou em 2019 - 2022 em comparação a legislatura anteior?
#       2 # Utilize Gráfico de pizza para representar os metadados.
# ----> 4 df_senadores[['IdentificacaoParlamentar.SexoParlamentar','numLegistlatura','IdentificacaoParlamentar.CodigoParlamentar']].groupby(['IdentificacaoParlamentar.SexoParlamentar','numLegistlatura']).count().reset_index()
#
# File ~\miniconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['numLegistlatura'] not in index"

# %% [markdown]
# "Se a saúde pública no Brasil parece estar ruim das pernas, isso jamais atingirá senadores, ex-senadores, suplentes que assumiram o cargo, tampouco seus cônjuges e dependentes. E para que isso seja possível, é exigido um único requisito destes políticos: exercício ininterrupto por 180 dias. Isso quer dizer que nenhum deles precisa contribuir para ter direito ao plano de saúde mais cobiçado do país."
#
# [fonte](https://gilbert92.jusbrasil.com.br/artigos/141608410/plano-de-saude-de-senadores-e-vitalicio-completo-e-estendido-a-conjuge-e-dependentes)
#
# com base na afirmação abaixo responda a alternativa abaixo:

# %%
# Quais são os Senadores Suplentes exerceram mais de 180 dias de mandato?
# Utilize Tabelas para representar os metadados.

# %%
# Existe uma Correlação entre idade do senador e gastos gerados por ele?
# Utilize Gráfico de disperssão para representar os metadados.

# %% [markdown]
# #### Dever de casa
#
# Integre as bases [profissões](https://legis.senado.leg.br/dadosabertos/docs/resource_ListaSenadorService.html?_gl=1*1m0s91v*_ga*MjEyNTA3MDAxOC4xNjgwNDc3NzU2*_ga_CW3ZH25XMK*MTY4MTUyMTA1Ny40LjEuMTY4MTUyMTMzNi4wLjAuMA..#resource_ListaSenadorService_profissaoSenadorXml_GET) e [historicoAcademico](https://legis.senado.leg.br/dadosabertos/docs/resource_ListaSenadorService.html?_gl=1*1m0s91v*_ga*MjEyNTA3MDAxOC4xNjgwNDc3NzU2*_ga_CW3ZH25XMK*MTY4MTUyMTA1Ny40LjEuMTY4MTUyMTMzNi4wLjAuMA..#resource_ListaSenadorService_historicoAcademicoSenadorXml_GET) no EDA e gere visualizações e insights com esses novos dados.

# %% [markdown]
# #### Desafio
#
# Correlacione o período da pandemia do COVID-19 com os gastos de CEAPS. Crie o merge dos dados e novas vizualizações sobre isso.
