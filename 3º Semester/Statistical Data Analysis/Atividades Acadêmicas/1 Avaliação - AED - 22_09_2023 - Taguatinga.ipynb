# %% [markdown]
# # Tema: Associação entre variáveis!
#
# Script para ajudar: https://colab.research.google.com/drive/1UxoKZB6DRJGpLA5vbpp8Qxrts34a3eY1?usp=sharing
#
# ## Associação entre variáveis qualitativas:
#
# - Tabelas de dupla entrada
# - Gráficos de barras
# - Teste qui-quadrado.
#
# ## Associação entre variáveis qualitativas e quantitativas
#
# - Medidas estatísticas entre grupo
# - ANOVA
#
#
# ## Associação entre variáveis quantitativas
#
# - Gráfico de dispersão
# - Correlação

# %% [markdown]
# ## Aplicação com visualização e exploração de dados
#
# Considere uma amostra dos dados de 100 mil clientes de um banco no arquivo dados_banco.csv. Estão disponíveis as variáveis:
#
# - Cliente: Identificador do cliente.
# - Sexo: Feminino (F) ou Masculino (M)
# - Idade: Idade do cliente, em anos completos.
# - Empresa: Tipo da empresa em que trabalha: Pública, Privada ou Autônomo
# - Salário: Salário declarado pelo cliente na abertura da conta, em reais.
# - Saldo_cc: Saldo em conta corrente, em reais.
# - Saldo_poupança: Saldo em poupança, em reais.
# - Saldo_investimento: Saldo em investimentos, em reais.
# - Devedor_cartao: Valor em atraso no cartão de crédito, em reais.
# - Inadimplente: Se o cliente é considerado inadimplente atualmente (1) ou não (0), de acordo com critérios preestabelecidos.

# %%
import os.path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats

# %matplotlib inline

# Dados banco - Leitura dos dados
dados = pd.read_csv("https://raw.githubusercontent.com/cibelerusso/VED/main/Dados/dados_banco.csv")
dados

# %%
dados.head()

# %% [markdown]
# ## Exercício 1
# ## Classifique as variaveis por tipo:
# * qualitativa nominal
# * qualitativa ordinal
# * quantitativa contínua
# * quantitativa discreta

# %% [markdown]
# ## Exercício 2
# ## Associação entre variáveis qualitativas e quantitativas
#
# 1.   Faça o cálculo da média aritmética da variável quantitativa por grupos qualitativos.
# 2.   Faça o boxplot da variável quantitativa por variável qualitativa
# 3.   Faça o teste de hipótese baseado em ANOVA para testar sé há dependencia entre as variáveis qualitativas e quantitativas.
#
# ## Considere os pares:
# * Idade & Sexo
# * Saldo Poupança & Empresa
# * Salário & Empresa

# %% [markdown]
# ## Exercício 3
# ## Associação entre variáveis qualitativas e qualitativas
#
# 1.   Faça a tabela de dupla entrada para verificar a distribuição dos dados.
# 2.   Faça o gráfico de barras da variável qualitativa por variável qualitativa
# 3.   Faça o teste de hipótese baseado no Qui-Quadrado para testar sé há dependencia entre as variáveis qualitativas.
#
# ## Considere os pares:
# * Empresa & Sexo
# * Inadimplência & Empresa
# * Sexo & Inadimplência

# %% [markdown]
# ## Exercício 4
# ## Associação entre variáveis quantitativas
#
# 1.   Faça o gráfico de disperção das variáveis quantitativas versus quantitativas.
# 3.   Calcule a correlação linear de Pearson entre as variáveis.
#
# ## Considere os pares:
# * Idade & Salário
# * Idade & Saldo Conta Corrente
# * Salário & Saldo Poupança

# %% [markdown]
# # Boa Prova!
